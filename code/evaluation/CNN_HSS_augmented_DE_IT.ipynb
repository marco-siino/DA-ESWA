# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/DA-ESWA/blob/main/code/evaluation/CNN_HSS_augmented_DE_IT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Investigating text data augmentation using back translation for author profiling
# - - -
# CNN ON HSS DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Hate Speech Spreaders Dataset augmented with both DE and IT backtranslation.
# Code by M. Siino.
#
# From the paper: "Investigating text data augmentation using back translation for author profiling" by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf

import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

os.environ['TF_CUDNN_DETERMINISTIC']='true'
os.environ['TF_DETERMINISTIC_OPS']='true'

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
urlTrainingSet = "https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-training-augmented-de-it.zip"
training_set = tf.keras.utils.get_file("pan21-author-profiling-training-2021-03-14-augmented.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSet="https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-cleaned.zip"
test_set = tf.keras.utils.get_file("pan21-author-profiling-test-without-gold.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSetAug="https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-cleaned-augmented-de-it.zip"
test_set_aug = tf.keras.utils.get_file("pan21-author-profiling-test-without-gold-augmented.zip", urlTestSetAug,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
# Out:
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-training-augmented-de-it.zip
# 2413924/2413924 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-cleaned.zip
# 652227/652227 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-cleaned-augmented-de-it.zip
# 1258895/1258895 [==============================] - 0s 0us/step

# %%
training_set_dir = os.path.join(os.path.dirname(training_set), 'pan21-author-profiling-training-2021-03-14-augmented')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan21-author-profiling-test-without-gold')
test_set_aug_dir = os.path.join(os.path.dirname(test_set_aug), 'pan21-author-profiling-test-without-gold-augmented')

# !ls -A
# Out:
# .config
# pan21-author-profiling-test-without-gold
# pan21-author-profiling-test-without-gold-augmented
# pan21-author-profiling-test-without-gold-augmented.zip
# pan21-author-profiling-test-without-gold.zip
# pan21-author-profiling-training-2021-03-14-augmented
# pan21-author-profiling-training-2021-03-14-augmented.zip
# sample_data

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')

# Make Py variables.
test_dir='test_dir_'

## Test Augmented Folders. ##
# First level directory.
if not os.path.exists('test_aug_dir_en'):
    os.makedirs('test_aug_dir_en')

# Class labels directory.
if not os.path.exists('test_aug_dir_en/0'):
    os.makedirs('test_aug_dir_en/0')
if not os.path.exists('test_aug_dir_en/1'):
    os.makedirs('test_aug_dir_en/1')

# Make Py variables.
test_aug_dir='test_aug_dir_'

# !ls -A
# Out:
# .config
# pan21-author-profiling-test-without-gold
# pan21-author-profiling-test-without-gold-augmented
# pan21-author-profiling-test-without-gold-augmented.zip
# pan21-author-profiling-test-without-gold.zip
# pan21-author-profiling-training-2021-03-14-augmented
# pan21-author-profiling-training-2021-03-14-augmented.zip
# sample_data
# test_aug_dir_en
# test_dir_en
# train_dir_en

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es ground truth file path for train_dir. 
language='en'

truth_file_training_dir_en=training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_en = truth_file_test_dir+'/'+'truth'+'.txt'

truth_file_test_aug_dir=test_set_aug_dir
truth_file_test_aug_path_en = truth_file_test_aug_dir+'/'+'truth'+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training and test dataset folders.

# %%
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_aug_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_aug_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_aug_dir+'/'+language+'/'+fNameXml, './test_aug_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Generate full dataset.

# %%
# Generate full randomized training set.
batch_size=1

en_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_aug_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_aug_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

train_ds=en_train_ds.shuffle(300,seed=1, reshuffle_each_iteration=False)
test_ds=en_test_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)
test_aug_ds=en_test_aug_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
test_aug_ds_size=len(test_aug_ds)
# Out:
# Found 200 files belonging to 2 classes.
# Found 100 files belonging to 2 classes.
# Found 100 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text.

# %%
# Preprocessing function to remove some noise due to the translation.
def clean_samples(input_data):
  tag_author_lang_en_removed = tf.strings.regex_replace(input_data,'<author lang="en"', '')
  tag_author_lang_en_cased_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'<Author lang="en"', '\n\n')
  tag_opening_document_miscased = tf.strings.regex_replace(tag_author_lang_en_cased_removed,'<Document>', '<document>')
  output_data = tf.strings.regex_replace(tag_opening_document_miscased,'</Document>', '</document>')
  return output_data

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 20000
  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

#opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Vectorization

# %%
print("\n\n* * * * VECTORIZATION STARTED * * * *")

# Preprocess training set to build a dictionary.
vectorize_layer = preprocess_and_adapt_ts(train_ds)

max_features=len(vectorize_layer.get_vocabulary()) + 1
print("Vocabulary size is:", max_features)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# * * * * VECTORIZATION STARTED * * * *
# Length of the longest sample is: 12800
# Vocabulary size is: 76985

# %% [markdown]
# ## Models definition, training and evaluation on original and on augmented test set.

# %%
tf.random.set_seed(1)

runs_accuracy = []
aug_runs_accuracy = []

for run in range(1,(num_runs+1)):
    epochs_accuracy = []
    aug_epochs_accuracy = []
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Conv1D(256,16,activation='relu'),
                                    layers.MaxPooling1D(),
                                    layers.Dropout(0.6),

                                    layers.Dense(512,activation='relu'),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer='RMSprop', metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        aug_score = model.evaluate(test_aug_ds, verbose=0)
        aug_accuracy = aug_score[1]
        print("Run: ",run,"/ Accuracy on test ORIGINAL at epoch ",epoch," is: ", accuracy[0],"\n")
        print("Run: ",run,"/ Accuracy on test AUGMENTED at epoch ",epoch," is: ", aug_accuracy,"\n")
        epochs_accuracy.append(accuracy[0])
        aug_epochs_accuracy.append(aug_accuracy)

    print("Accuracies on ORIGINAL over epochs:",epochs_accuracy,"\n")
    runs_accuracy.append(max(epochs_accuracy))
    print("Accuracies on AUGMENTED over epochs:",aug_epochs_accuracy,"\n\n")
    aug_runs_accuracy.append(max(aug_epochs_accuracy))

runs_accuracy.sort()
aug_runs_accuracy.sort()
print("\n\n Over all runs maximum accuracies on ORIGINAL test set are:", runs_accuracy)
print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
print("\n\n Over all runs maximum accuracies on AUGMENTED test set are:", aug_runs_accuracy)
print("The median for English is:",aug_runs_accuracy[2],"\n\n\n")

# Final Result on Original Test set
if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
  max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
else:
  max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on Original Test set -> ",final_result)

# Final result on AUGMENTED test set.
if (aug_runs_accuracy[2]-aug_runs_accuracy[0])>(aug_runs_accuracy[4]-aug_runs_accuracy[2]):
  max_range_from_median = aug_runs_accuracy[2]-aug_runs_accuracy[0]
else:
  max_range_from_median = aug_runs_accuracy[4]-aug_runs_accuracy[2]
final_result = str(aug_runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on AUGMENTED Test set -> ",final_result)
# Out:
# 200/200 [==============================] - 57s 231ms/step - loss: 0.7055 - binary_accuracy: 0.4600 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6964 - binary_accuracy: 0.4550 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6958 - binary_accuracy: 0.4400 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6951 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6949 - binary_accuracy: 0.4500 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6949 - binary_accuracy: 0.4200 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6946 - binary_accuracy: 0.4600 - val_loss: 0.6930 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy on test ORIGINAL at epoch  6  is:  0.5799999833106995
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  6  is:  0.5600000023841858
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6931 - binary_accuracy: 0.4950 - val_loss: 0.6919 - val_binary_accuracy: 0.5400
# Run:  1 / Accuracy on test ORIGINAL at epoch  7  is:  0.5400000214576721
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  7  is:  0.5199999809265137
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6865 - binary_accuracy: 0.5200 - val_loss: 0.6873 - val_binary_accuracy: 0.5700
# Run:  1 / Accuracy on test ORIGINAL at epoch  8  is:  0.5699999928474426
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  8  is:  0.5699999928474426
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6714 - binary_accuracy: 0.5650 - val_loss: 0.6807 - val_binary_accuracy: 0.5500
# Run:  1 / Accuracy on test ORIGINAL at epoch  9  is:  0.550000011920929
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  9  is:  0.6000000238418579
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6387 - binary_accuracy: 0.6550 - val_loss: 0.6730 - val_binary_accuracy: 0.5600
# Run:  1 / Accuracy on test ORIGINAL at epoch  10  is:  0.5600000023841858
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  10  is:  0.6000000238418579
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5868 - binary_accuracy: 0.7250 - val_loss: 0.6682 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy on test ORIGINAL at epoch  11  is:  0.5799999833106995
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  11  is:  0.6399999856948853
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5104 - binary_accuracy: 0.8100 - val_loss: 0.7164 - val_binary_accuracy: 0.5300
# Run:  1 / Accuracy on test ORIGINAL at epoch  12  is:  0.5299999713897705
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  12  is:  0.6499999761581421
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3834 - binary_accuracy: 0.8450 - val_loss: 1.3559 - val_binary_accuracy: 0.5100
# Run:  1 / Accuracy on test ORIGINAL at epoch  13  is:  0.5099999904632568
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  13  is:  0.6700000166893005
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.2718 - binary_accuracy: 0.8700 - val_loss: 1.7645 - val_binary_accuracy: 0.5100
# Run:  1 / Accuracy on test ORIGINAL at epoch  14  is:  0.5099999904632568
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  14  is:  0.6100000143051147
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.1859 - binary_accuracy: 0.9300 - val_loss: 2.5548 - val_binary_accuracy: 0.5100
# Run:  1 / Accuracy on test ORIGINAL at epoch  15  is:  0.5099999904632568
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  15  is:  0.6200000047683716
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.1092 - binary_accuracy: 0.9550 - val_loss: 3.3199 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  16  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  16  is:  0.6100000143051147
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0653 - binary_accuracy: 0.9850 - val_loss: 4.0053 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  17  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  17  is:  0.6000000238418579
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0231 - binary_accuracy: 0.9950 - val_loss: 4.7398 - val_binary_accuracy: 0.5100
# Run:  1 / Accuracy on test ORIGINAL at epoch  18  is:  0.5099999904632568
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  18  is:  0.6200000047683716
#
# 200/200 [==============================] - 15s 75ms/step - loss: 0.0069 - binary_accuracy: 1.0000 - val_loss: 5.0513 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  19  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  19  is:  0.6000000238418579
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5799999833106995, 0.5400000214576721, 0.5699999928474426, 0.550000011920929, 0.5600000023841858, 0.5799999833106995, 0.5299999713897705, 0.5099999904632568, 0.5099999904632568, 0.5099999904632568, 0.5, 0.5, 0.5099999904632568, 0.5]
#
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5600000023841858, 0.5199999809265137, 0.5699999928474426, 0.6000000238418579, 0.6000000238418579, 0.6399999856948853, 0.6499999761581421, 0.6700000166893005, 0.6100000143051147, 0.6200000047683716, 0.6100000143051147, 0.6000000238418579, 0.6200000047683716, 0.6000000238418579]
#
#
# 200/200 [==============================] - 36s 171ms/step - loss: 0.7070 - binary_accuracy: 0.4550 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6967 - binary_accuracy: 0.4100 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6954 - binary_accuracy: 0.3950 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6949 - binary_accuracy: 0.4250 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6945 - binary_accuracy: 0.4550 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6945 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6946 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  6  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6942 - binary_accuracy: 0.4800 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  7  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  7  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6935 - binary_accuracy: 0.5000 - val_loss: 0.6927 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  8  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  8  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6894 - binary_accuracy: 0.5050 - val_loss: 0.6896 - val_binary_accuracy: 0.5600
# Run:  2 / Accuracy on test ORIGINAL at epoch  9  is:  0.5600000023841858
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  9  is:  0.5199999809265137
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6774 - binary_accuracy: 0.5400 - val_loss: 0.6836 - val_binary_accuracy: 0.5400
# Run:  2 / Accuracy on test ORIGINAL at epoch  10  is:  0.5400000214576721
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  10  is:  0.550000011920929
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6550 - binary_accuracy: 0.5900 - val_loss: 0.6762 - val_binary_accuracy: 0.5600
# Run:  2 / Accuracy on test ORIGINAL at epoch  11  is:  0.5600000023841858
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  11  is:  0.6000000238418579
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6214 - binary_accuracy: 0.6600 - val_loss: 0.6684 - val_binary_accuracy: 0.5700
# Run:  2 / Accuracy on test ORIGINAL at epoch  12  is:  0.5699999928474426
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  12  is:  0.5799999833106995
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.5610 - binary_accuracy: 0.7350 - val_loss: 0.6634 - val_binary_accuracy: 0.5800
# Run:  2 / Accuracy on test ORIGINAL at epoch  13  is:  0.5799999833106995
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  13  is:  0.5899999737739563
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4754 - binary_accuracy: 0.8200 - val_loss: 0.7770 - val_binary_accuracy: 0.5300
# Run:  2 / Accuracy on test ORIGINAL at epoch  14  is:  0.5299999713897705
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  14  is:  0.6299999952316284
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.3304 - binary_accuracy: 0.8650 - val_loss: 1.5668 - val_binary_accuracy: 0.5100
# Run:  2 / Accuracy on test ORIGINAL at epoch  15  is:  0.5099999904632568
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  15  is:  0.6399999856948853
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2173 - binary_accuracy: 0.9000 - val_loss: 2.0378 - val_binary_accuracy: 0.5200
# Run:  2 / Accuracy on test ORIGINAL at epoch  16  is:  0.5199999809265137
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  16  is:  0.6100000143051147
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.1446 - binary_accuracy: 0.9500 - val_loss: 2.4201 - val_binary_accuracy: 0.5100
# Run:  2 / Accuracy on test ORIGINAL at epoch  17  is:  0.5099999904632568
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  17  is:  0.5899999737739563
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0683 - binary_accuracy: 0.9700 - val_loss: 2.6822 - val_binary_accuracy: 0.5300
# Run:  2 / Accuracy on test ORIGINAL at epoch  18  is:  0.5299999713897705
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  18  is:  0.5799999833106995
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0463 - binary_accuracy: 0.9900 - val_loss: 4.9244 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  19  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  19  is:  0.6800000071525574
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5600000023841858, 0.5400000214576721, 0.5600000023841858, 0.5699999928474426, 0.5799999833106995, 0.5299999713897705, 0.5099999904632568, 0.5199999809265137, 0.5099999904632568, 0.5299999713897705, 0.5]
#
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5199999809265137, 0.550000011920929, 0.6000000238418579, 0.5799999833106995, 0.5899999737739563, 0.6299999952316284, 0.6399999856948853, 0.6100000143051147, 0.5899999737739563, 0.5799999833106995, 0.6800000071525574]
#
#
# 200/200 [==============================] - 35s 166ms/step - loss: 0.7050 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6961 - binary_accuracy: 0.4550 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 12s 60ms/step - loss: 0.6954 - binary_accuracy: 0.4250 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 12s 61ms/step - loss: 0.6948 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 13s 62ms/step - loss: 0.6943 - binary_accuracy: 0.4600 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6947 - binary_accuracy: 0.4150 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6946 - binary_accuracy: 0.4300 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  6  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6945 - binary_accuracy: 0.4050 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  7  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  7  is:  0.5
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6941 - binary_accuracy: 0.4450 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  8  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  8  is:  0.5
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6940 - binary_accuracy: 0.4700 - val_loss: 0.6928 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  9  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  9  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6909 - binary_accuracy: 0.5200 - val_loss: 0.6907 - val_binary_accuracy: 0.5500
# Run:  3 / Accuracy on test ORIGINAL at epoch  10  is:  0.550000011920929
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  10  is:  0.5299999713897705
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6814 - binary_accuracy: 0.5600 - val_loss: 0.6849 - val_binary_accuracy: 0.5500
# Run:  3 / Accuracy on test ORIGINAL at epoch  11  is:  0.550000011920929
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  11  is:  0.5699999928474426
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6594 - binary_accuracy: 0.6000 - val_loss: 0.6773 - val_binary_accuracy: 0.5700
# Run:  3 / Accuracy on test ORIGINAL at epoch  12  is:  0.5699999928474426
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  12  is:  0.6000000238418579
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6247 - binary_accuracy: 0.6900 - val_loss: 0.6704 - val_binary_accuracy: 0.5200
# Run:  3 / Accuracy on test ORIGINAL at epoch  13  is:  0.5199999809265137
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  13  is:  0.6100000143051147
#
# 200/200 [==============================] - 13s 67ms/step - loss: 0.5736 - binary_accuracy: 0.7500 - val_loss: 0.6656 - val_binary_accuracy: 0.5900
# Run:  3 / Accuracy on test ORIGINAL at epoch  14  is:  0.5899999737739563
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  14  is:  0.6100000143051147
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.4829 - binary_accuracy: 0.8150 - val_loss: 0.8229 - val_binary_accuracy: 0.5300
# Run:  3 / Accuracy on test ORIGINAL at epoch  15  is:  0.5299999713897705
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  15  is:  0.6499999761581421
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.3542 - binary_accuracy: 0.8450 - val_loss: 1.3500 - val_binary_accuracy: 0.5200
# Run:  3 / Accuracy on test ORIGINAL at epoch  16  is:  0.5199999809265137
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  16  is:  0.6299999952316284
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.2342 - binary_accuracy: 0.8900 - val_loss: 1.9404 - val_binary_accuracy: 0.5200
# Run:  3 / Accuracy on test ORIGINAL at epoch  17  is:  0.5199999809265137
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  17  is:  0.6000000238418579
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.1436 - binary_accuracy: 0.9450 - val_loss: 2.3585 - val_binary_accuracy: 0.5100
# Run:  3 / Accuracy on test ORIGINAL at epoch  18  is:  0.5099999904632568
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  18  is:  0.5799999833106995
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.0944 - binary_accuracy: 0.9650 - val_loss: 3.1171 - val_binary_accuracy: 0.5100
# Run:  3 / Accuracy on test ORIGINAL at epoch  19  is:  0.5099999904632568
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  19  is:  0.6000000238418579
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.550000011920929, 0.550000011920929, 0.5699999928474426, 0.5199999809265137, 0.5899999737739563, 0.5299999713897705, 0.5199999809265137, 0.5199999809265137, 0.5099999904632568, 0.5099999904632568]
#
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5299999713897705, 0.5699999928474426, 0.6000000238418579, 0.6100000143051147, 0.6100000143051147, 0.6499999761581421, 0.6299999952316284, 0.6000000238418579, 0.5799999833106995, 0.6000000238418579]
#
#
# 200/200 [==============================] - 35s 170ms/step - loss: 0.7062 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6962 - binary_accuracy: 0.4000 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6950 - binary_accuracy: 0.4100 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6950 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6947 - binary_accuracy: 0.4250 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 13s 64ms/step - loss: 0.6944 - binary_accuracy: 0.4600 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6946 - binary_accuracy: 0.4300 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  6  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6939 - binary_accuracy: 0.4800 - val_loss: 0.6928 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  7  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  7  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6905 - binary_accuracy: 0.5150 - val_loss: 0.6904 - val_binary_accuracy: 0.5300
# Run:  4 / Accuracy on test ORIGINAL at epoch  8  is:  0.5299999713897705
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  8  is:  0.5199999809265137
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6799 - binary_accuracy: 0.5300 - val_loss: 0.6852 - val_binary_accuracy: 0.5600
# Run:  4 / Accuracy on test ORIGINAL at epoch  9  is:  0.5600000023841858
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  9  is:  0.5699999928474426
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6577 - binary_accuracy: 0.6050 - val_loss: 0.6786 - val_binary_accuracy: 0.5500
# Run:  4 / Accuracy on test ORIGINAL at epoch  10  is:  0.550000011920929
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  10  is:  0.5799999833106995
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6192 - binary_accuracy: 0.6700 - val_loss: 0.6720 - val_binary_accuracy: 0.5600
# Run:  4 / Accuracy on test ORIGINAL at epoch  11  is:  0.5600000023841858
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  11  is:  0.6000000238418579
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.5680 - binary_accuracy: 0.7550 - val_loss: 0.6751 - val_binary_accuracy: 0.5800
# Run:  4 / Accuracy on test ORIGINAL at epoch  12  is:  0.5799999833106995
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  12  is:  0.6000000238418579
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.4622 - binary_accuracy: 0.8100 - val_loss: 0.9389 - val_binary_accuracy: 0.5200
# Run:  4 / Accuracy on test ORIGINAL at epoch  13  is:  0.5199999809265137
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  13  is:  0.6499999761581421
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.3266 - binary_accuracy: 0.8550 - val_loss: 1.6987 - val_binary_accuracy: 0.5100
# Run:  4 / Accuracy on test ORIGINAL at epoch  14  is:  0.5099999904632568
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  14  is:  0.6700000166893005
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2569 - binary_accuracy: 0.9050 - val_loss: 2.4059 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  15  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  15  is:  0.6299999952316284
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.1507 - binary_accuracy: 0.9450 - val_loss: 3.0261 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  16  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  16  is:  0.6499999761581421
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.0938 - binary_accuracy: 0.9650 - val_loss: 3.1226 - val_binary_accuracy: 0.5100
# Run:  4 / Accuracy on test ORIGINAL at epoch  17  is:  0.5099999904632568
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  17  is:  0.6100000143051147
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.0319 - binary_accuracy: 0.9900 - val_loss: 3.9726 - val_binary_accuracy: 0.5100
# Run:  4 / Accuracy on test ORIGINAL at epoch  18  is:  0.5099999904632568
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  18  is:  0.6000000238418579
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.0498 - binary_accuracy: 0.9900 - val_loss: 6.1627 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  19  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  19  is:  0.6399999856948853
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5299999713897705, 0.5600000023841858, 0.550000011920929, 0.5600000023841858, 0.5799999833106995, 0.5199999809265137, 0.5099999904632568, 0.5, 0.5, 0.5099999904632568, 0.5099999904632568, 0.5]
#
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5199999809265137, 0.5699999928474426, 0.5799999833106995, 0.6000000238418579, 0.6000000238418579, 0.6499999761581421, 0.6700000166893005, 0.6299999952316284, 0.6499999761581421, 0.6100000143051147, 0.6000000238418579, 0.6399999856948853]
#
#
# 200/200 [==============================] - 35s 168ms/step - loss: 0.7067 - binary_accuracy: 0.4600 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6964 - binary_accuracy: 0.4400 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6954 - binary_accuracy: 0.4200 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 13s 67ms/step - loss: 0.6951 - binary_accuracy: 0.4350 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6948 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6945 - binary_accuracy: 0.4600 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6945 - binary_accuracy: 0.4300 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  6  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6944 - binary_accuracy: 0.4300 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  7  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  7  is:  0.5
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6933 - binary_accuracy: 0.4850 - val_loss: 0.6926 - val_binary_accuracy: 0.5800
# Run:  5 / Accuracy on test ORIGINAL at epoch  8  is:  0.5799999833106995
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  8  is:  0.5600000023841858
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6883 - binary_accuracy: 0.5150 - val_loss: 0.6896 - val_binary_accuracy: 0.5300
# Run:  5 / Accuracy on test ORIGINAL at epoch  9  is:  0.5299999713897705
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  9  is:  0.550000011920929
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.6735 - binary_accuracy: 0.5600 - val_loss: 0.6840 - val_binary_accuracy: 0.5800
# Run:  5 / Accuracy on test ORIGINAL at epoch  10  is:  0.5799999833106995
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  10  is:  0.5799999833106995
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6516 - binary_accuracy: 0.6350 - val_loss: 0.6773 - val_binary_accuracy: 0.5600
# Run:  5 / Accuracy on test ORIGINAL at epoch  11  is:  0.5600000023841858
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  11  is:  0.6100000143051147
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.6122 - binary_accuracy: 0.6900 - val_loss: 0.6723 - val_binary_accuracy: 0.5500
# Run:  5 / Accuracy on test ORIGINAL at epoch  12  is:  0.550000011920929
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  12  is:  0.6200000047683716
#
# 200/200 [==============================] - 13s 66ms/step - loss: 0.5527 - binary_accuracy: 0.7850 - val_loss: 0.6816 - val_binary_accuracy: 0.5500
# Run:  5 / Accuracy on test ORIGINAL at epoch  13  is:  0.550000011920929
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  13  is:  0.6299999952316284
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.4357 - binary_accuracy: 0.8100 - val_loss: 1.1710 - val_binary_accuracy: 0.5100
# Run:  5 / Accuracy on test ORIGINAL at epoch  14  is:  0.5099999904632568
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  14  is:  0.6600000262260437
#
# 200/200 [==============================] - 13s 66ms/step - loss: 0.3127 - binary_accuracy: 0.8600 - val_loss: 1.8955 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  15  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  15  is:  0.6600000262260437
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.2226 - binary_accuracy: 0.9050 - val_loss: 2.6117 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  16  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  16  is:  0.6600000262260437
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.1464 - binary_accuracy: 0.9400 - val_loss: 2.9653 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  17  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  17  is:  0.6100000143051147
#
# 200/200 [==============================] - 13s 63ms/step - loss: 0.0613 - binary_accuracy: 0.9750 - val_loss: 3.8376 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  18  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  18  is:  0.6100000143051147
#
# 200/200 [==============================] - 12s 62ms/step - loss: 0.0353 - binary_accuracy: 0.9900 - val_loss: 5.3392 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  19  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  19  is:  0.6899999976158142
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5799999833106995, 0.5299999713897705, 0.5799999833106995, 0.5600000023841858, 0.550000011920929, 0.550000011920929, 0.5099999904632568, 0.5, 0.5, 0.5, 0.5, 0.5]
#
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5600000023841858, 0.550000011920929, 0.5799999833106995, 0.6100000143051147, 0.6200000047683716, 0.6299999952316284, 0.6600000262260437, 0.6600000262260437, 0.6600000262260437, 0.6100000143051147, 0.6100000143051147, 0.6899999976158142]
#
#
#
#
#  Over all runs maximum accuracies on ORIGINAL test set are: [0.5799999833106995, 0.5799999833106995, 0.5799999833106995, 0.5799999833106995, 0.5899999737739563]
# The median for English is: 0.5799999833106995
#
#
#
#
#
#  Over all runs maximum accuracies on AUGMENTED test set are: [0.6499999761581421, 0.6700000166893005, 0.6700000166893005, 0.6800000071525574, 0.6899999976158142]
# The median for English is: 0.6700000166893005
#
#
#
# CNN Accuracy Score on Original Test set ->  0.5799999833106995 +/- 0.009999990463256836
# CNN Accuracy Score on AUGMENTED Test set ->  0.6700000166893005 +/- 0.020000040531158447
