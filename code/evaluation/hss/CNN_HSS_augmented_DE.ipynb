# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/DA-ESWA/blob/main/code/evaluation/hss/CNN_HSS_augmented_DE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Investigating text data augmentation using back translation for author profiling
# - - -
# CNN ON HSS DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Hate Speech Spreaders Dataset augmented with DE backtranslation.
# Code by M. Siino.
#
# From the paper: "Investigating text data augmentation using back translation for author profiling" by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf

import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

os.environ['TF_CUDNN_DETERMINISTIC']='true'
os.environ['TF_DETERMINISTIC_OPS']='true'

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
urlTrainingSet = "https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-training-augmented-de.zip"
training_set = tf.keras.utils.get_file("pan21-author-profiling-training-2021-03-14-augmented.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSet="https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-cleaned.zip"
test_set = tf.keras.utils.get_file("pan21-author-profiling-test-without-gold.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSetAug="https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-augmented-de.zip"
test_set_aug = tf.keras.utils.get_file("pan21-author-profiling-test-without-gold-augmented.zip", urlTestSetAug,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
# Out:
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-training-augmented-de.zip
# 1891842/1891842 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-cleaned.zip
# 652227/652227 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/hss/hss-test-augmented-de.zip
# 1000245/1000245 [==============================] - 0s 0us/step

# %%
training_set_dir = os.path.join(os.path.dirname(training_set), 'pan21-author-profiling-training-2021-03-14-augmented')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan21-author-profiling-test-without-gold')
test_set_aug_dir = os.path.join(os.path.dirname(test_set_aug), 'pan21-author-profiling-test-without-gold-augmented')

# !ls -A
# Out:
# .config
# hss-training-augmented-de
# pan21-author-profiling-test-without-gold
# pan21-author-profiling-test-without-gold-augmented
# pan21-author-profiling-test-without-gold-augmented.zip
# pan21-author-profiling-test-without-gold.zip
# pan21-author-profiling-training-2021-03-14-augmented.zip
# sample_data

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')

# Make Py variables.
test_dir='test_dir_'

## Test Augmented Folders. ##
# First level directory.
if not os.path.exists('test_aug_dir_en'):
    os.makedirs('test_aug_dir_en')

# Class labels directory.
if not os.path.exists('test_aug_dir_en/0'):
    os.makedirs('test_aug_dir_en/0')
if not os.path.exists('test_aug_dir_en/1'):
    os.makedirs('test_aug_dir_en/1')

# Make Py variables.
test_aug_dir='test_aug_dir_'

# !ls -A
# Out:
# .config
# hss-training-augmented-de
# pan21-author-profiling-test-without-gold
# pan21-author-profiling-test-without-gold-augmented
# pan21-author-profiling-test-without-gold-augmented.zip
# pan21-author-profiling-test-without-gold.zip
# pan21-author-profiling-training-2021-03-14-augmented.zip
# sample_data
# test_aug_dir_en
# test_dir_en
# train_dir_en

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es ground truth file path for train_dir. 
language='en'

truth_file_training_dir_en =  training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_en = truth_file_test_dir+'/'+'truth'+'.txt'

truth_file_test_aug_dir=test_set_aug_dir
truth_file_test_aug_path_en = truth_file_test_aug_dir+'/'+'truth'+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training and test dataset folders.

# %%
# Open the file truth.txt with read only permit.
f = open('/content/pan21-author-profiling-training-2021-03-14-augmented/truth.txt', "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_aug_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_aug_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_aug_dir+'/'+language+'/'+fNameXml, './test_aug_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Generate full dataset.

# %%
# Generate full randomized training set.
batch_size=1

en_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_aug_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_aug_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

train_ds=en_train_ds.shuffle(300,seed=1, reshuffle_each_iteration=False)
test_ds=en_test_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)
test_aug_ds=en_test_aug_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
test_aug_ds_size=len(test_aug_ds)
# Out:
# Found 200 files belonging to 2 classes.
# Found 100 files belonging to 2 classes.
# Found 100 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text.

# %%
# Preprocessing function to remove some noise due to the translation.
def clean_samples(input_data):
  tag_author_lang_en_removed = tf.strings.regex_replace(input_data,'<author lang="en"', '')
  tag_author_lang_en_cased_removed = tf.strings.regex_replace(tag_author_lang_en_removed,'<Author lang="en"', '\n\n')
  tag_opening_document_miscased = tf.strings.regex_replace(tag_author_lang_en_cased_removed,'<Document>', '<document>')
  output_data = tf.strings.regex_replace(tag_opening_document_miscased,'</Document>', '</document>')
  return output_data

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 20000
  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

#opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Vectorization

# %%
print("\n\n* * * * VECTORIZATION STARTED * * * *")

# Preprocess training set to build a dictionary.
vectorize_layer = preprocess_and_adapt_ts(train_ds)

max_features=len(vectorize_layer.get_vocabulary()) + 1
print("Vocabulary size is:", max_features)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# * * * * VECTORIZATION STARTED * * * *
# Length of the longest sample is: 8554
# Vocabulary size is: 68301

# %% [markdown]
# ## Models definition, training and evaluation on original and on augmented test set.

# %%
tf.random.set_seed(1)

runs_accuracy = []
aug_runs_accuracy = []

for run in range(1,(num_runs+1)):
    epochs_accuracy = []
    aug_epochs_accuracy = []
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Conv1D(256,16,activation='relu'),
                                    layers.MaxPooling1D(),
                                    layers.Dropout(0.6),

                                    layers.Dense(512,activation='relu'),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer='RMSprop', metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        aug_score = model.evaluate(test_aug_ds, verbose=0)
        aug_accuracy = aug_score[1]
        print("Run: ",run,"/ Accuracy on test ORIGINAL at epoch ",epoch," is: ", accuracy[0],"\n")
        print("Run: ",run,"/ Accuracy on test AUGMENTED at epoch ",epoch," is: ", aug_accuracy,"\n")
        epochs_accuracy.append(accuracy[0])
        aug_epochs_accuracy.append(aug_accuracy)

    print("Accuracies on ORIGINAL over epochs:",epochs_accuracy,"\n")
    runs_accuracy.append(max(epochs_accuracy))
    print("Accuracies on AUGMENTED over epochs:",aug_epochs_accuracy,"\n\n")
    aug_runs_accuracy.append(max(aug_epochs_accuracy))

runs_accuracy.sort()
aug_runs_accuracy.sort()
print("\n\n Over all runs maximum accuracies on ORIGINAL test set are:", runs_accuracy)
print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
print("\n\n Over all runs maximum accuracies on AUGMENTED test set are:", aug_runs_accuracy)
print("The median for English is:",aug_runs_accuracy[2],"\n\n\n")

# Final Result on Original Test set
if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
  max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
else:
  max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on Original Test set -> ",final_result)

# Final result on AUGMENTED test set.
if (aug_runs_accuracy[2]-aug_runs_accuracy[0])>(aug_runs_accuracy[4]-aug_runs_accuracy[2]):
  max_range_from_median = aug_runs_accuracy[2]-aug_runs_accuracy[0]
else:
  max_range_from_median = aug_runs_accuracy[4]-aug_runs_accuracy[2]
final_result = str(aug_runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on AUGMENTED Test set -> ",final_result)
# Out:
# 200/200 [==============================] - 56s 231ms/step - loss: 0.7069 - binary_accuracy: 0.4250 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6962 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6954 - binary_accuracy: 0.4250 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6946 - binary_accuracy: 0.4500 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6945 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.6945 - binary_accuracy: 0.4100 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6945 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  6  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6947 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  7  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  7  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6944 - binary_accuracy: 0.4050 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  8  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  8  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6945 - binary_accuracy: 0.4450 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  9  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  9  is:  0.5
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.6940 - binary_accuracy: 0.4500 - val_loss: 0.6930 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  10  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  10  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6934 - binary_accuracy: 0.4900 - val_loss: 0.6918 - val_binary_accuracy: 0.5500
# Run:  1 / Accuracy on test ORIGINAL at epoch  11  is:  0.550000011920929
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  11  is:  0.5699999928474426
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6862 - binary_accuracy: 0.5150 - val_loss: 0.6857 - val_binary_accuracy: 0.5300
# Run:  1 / Accuracy on test ORIGINAL at epoch  12  is:  0.5299999713897705
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  12  is:  0.5600000023841858
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.6703 - binary_accuracy: 0.5700 - val_loss: 0.6771 - val_binary_accuracy: 0.5300
# Run:  1 / Accuracy on test ORIGINAL at epoch  13  is:  0.5299999713897705
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  13  is:  0.5899999737739563
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6423 - binary_accuracy: 0.6400 - val_loss: 0.6682 - val_binary_accuracy: 0.5500
# Run:  1 / Accuracy on test ORIGINAL at epoch  14  is:  0.550000011920929
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  14  is:  0.6000000238418579
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.5946 - binary_accuracy: 0.7300 - val_loss: 0.6583 - val_binary_accuracy: 0.5900
# Run:  1 / Accuracy on test ORIGINAL at epoch  15  is:  0.5899999737739563
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  15  is:  0.6100000143051147
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.5324 - binary_accuracy: 0.7850 - val_loss: 0.6721 - val_binary_accuracy: 0.5800
# Run:  1 / Accuracy on test ORIGINAL at epoch  16  is:  0.5799999833106995
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  16  is:  0.6299999952316284
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.4110 - binary_accuracy: 0.8250 - val_loss: 0.9919 - val_binary_accuracy: 0.5200
# Run:  1 / Accuracy on test ORIGINAL at epoch  17  is:  0.5199999809265137
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  17  is:  0.6600000262260437
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2817 - binary_accuracy: 0.8900 - val_loss: 1.4174 - val_binary_accuracy: 0.5200
# Run:  1 / Accuracy on test ORIGINAL at epoch  18  is:  0.5199999809265137
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  18  is:  0.6700000166893005
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.1968 - binary_accuracy: 0.9300 - val_loss: 2.4470 - val_binary_accuracy: 0.5100
# Run:  1 / Accuracy on test ORIGINAL at epoch  19  is:  0.5099999904632568
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  19  is:  0.6200000047683716
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.550000011920929, 0.5299999713897705, 0.5299999713897705, 0.550000011920929, 0.5899999737739563, 0.5799999833106995, 0.5199999809265137, 0.5199999809265137, 0.5099999904632568]
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5699999928474426, 0.5600000023841858, 0.5899999737739563, 0.6000000238418579, 0.6100000143051147, 0.6299999952316284, 0.6600000262260437, 0.6700000166893005, 0.6200000047683716]
#
#
# 200/200 [==============================] - 35s 169ms/step - loss: 0.7059 - binary_accuracy: 0.4250 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6962 - binary_accuracy: 0.4400 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6951 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6948 - binary_accuracy: 0.4550 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6947 - binary_accuracy: 0.4500 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6941 - binary_accuracy: 0.4750 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 11s 55ms/step - loss: 0.6942 - binary_accuracy: 0.4500 - val_loss: 0.6927 - val_binary_accuracy: 0.5500
# Run:  2 / Accuracy on test ORIGINAL at epoch  6  is:  0.550000011920929
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  6  is:  0.5199999809265137
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6911 - binary_accuracy: 0.5100 - val_loss: 0.6891 - val_binary_accuracy: 0.5300
# Run:  2 / Accuracy on test ORIGINAL at epoch  7  is:  0.5299999713897705
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  7  is:  0.5400000214576721
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6796 - binary_accuracy: 0.5550 - val_loss: 0.6811 - val_binary_accuracy: 0.5700
# Run:  2 / Accuracy on test ORIGINAL at epoch  8  is:  0.5699999928474426
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  8  is:  0.5699999928474426
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.6582 - binary_accuracy: 0.5850 - val_loss: 0.6723 - val_binary_accuracy: 0.5600
# Run:  2 / Accuracy on test ORIGINAL at epoch  9  is:  0.5600000023841858
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  9  is:  0.6000000238418579
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6188 - binary_accuracy: 0.6750 - val_loss: 0.6610 - val_binary_accuracy: 0.5600
# Run:  2 / Accuracy on test ORIGINAL at epoch  10  is:  0.5600000023841858
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  10  is:  0.6100000143051147
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.5610 - binary_accuracy: 0.7650 - val_loss: 0.6510 - val_binary_accuracy: 0.5700
# Run:  2 / Accuracy on test ORIGINAL at epoch  11  is:  0.5699999928474426
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  11  is:  0.6299999952316284
#
# 200/200 [==============================] - 10s 48ms/step - loss: 0.4744 - binary_accuracy: 0.8200 - val_loss: 0.7184 - val_binary_accuracy: 0.5700
# Run:  2 / Accuracy on test ORIGINAL at epoch  12  is:  0.5699999928474426
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  12  is:  0.6600000262260437
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.3468 - binary_accuracy: 0.8500 - val_loss: 1.0757 - val_binary_accuracy: 0.5500
# Run:  2 / Accuracy on test ORIGINAL at epoch  13  is:  0.550000011920929
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  13  is:  0.6499999761581421
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.2385 - binary_accuracy: 0.9050 - val_loss: 1.6585 - val_binary_accuracy: 0.5200
# Run:  2 / Accuracy on test ORIGINAL at epoch  14  is:  0.5199999809265137
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  14  is:  0.6499999761581421
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.1540 - binary_accuracy: 0.9350 - val_loss: 1.8312 - val_binary_accuracy: 0.5400
# Run:  2 / Accuracy on test ORIGINAL at epoch  15  is:  0.5400000214576721
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  15  is:  0.6399999856948853
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.0742 - binary_accuracy: 0.9650 - val_loss: 3.6046 - val_binary_accuracy: 0.5100
# Run:  2 / Accuracy on test ORIGINAL at epoch  16  is:  0.5099999904632568
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  16  is:  0.6100000143051147
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.0379 - binary_accuracy: 0.9850 - val_loss: 2.4402 - val_binary_accuracy: 0.5500
# Run:  2 / Accuracy on test ORIGINAL at epoch  17  is:  0.550000011920929
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  17  is:  0.5799999833106995
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.0175 - binary_accuracy: 0.9950 - val_loss: 3.4050 - val_binary_accuracy: 0.5200
# Run:  2 / Accuracy on test ORIGINAL at epoch  18  is:  0.5199999809265137
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  18  is:  0.6399999856948853
#
# 200/200 [==============================] - 10s 48ms/step - loss: 0.0081 - binary_accuracy: 1.0000 - val_loss: 6.4527 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  19  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  19  is:  0.6100000143051147
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.550000011920929, 0.5299999713897705, 0.5699999928474426, 0.5600000023841858, 0.5600000023841858, 0.5699999928474426, 0.5699999928474426, 0.550000011920929, 0.5199999809265137, 0.5400000214576721, 0.5099999904632568, 0.550000011920929, 0.5199999809265137, 0.5]
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5199999809265137, 0.5400000214576721, 0.5699999928474426, 0.6000000238418579, 0.6100000143051147, 0.6299999952316284, 0.6600000262260437, 0.6499999761581421, 0.6499999761581421, 0.6399999856948853, 0.6100000143051147, 0.5799999833106995, 0.6399999856948853, 0.6100000143051147]
#
#
# 200/200 [==============================] - 35s 168ms/step - loss: 0.7049 - binary_accuracy: 0.4250 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6959 - binary_accuracy: 0.4200 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6953 - binary_accuracy: 0.4150 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6946 - binary_accuracy: 0.4400 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6944 - binary_accuracy: 0.4650 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6942 - binary_accuracy: 0.4550 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6944 - binary_accuracy: 0.4650 - val_loss: 0.6930 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  6  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.6923 - binary_accuracy: 0.4950 - val_loss: 0.6909 - val_binary_accuracy: 0.5300
# Run:  3 / Accuracy on test ORIGINAL at epoch  7  is:  0.5299999713897705
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  7  is:  0.5199999809265137
#
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6853 - binary_accuracy: 0.5200 - val_loss: 0.6850 - val_binary_accuracy: 0.5600
# Run:  3 / Accuracy on test ORIGINAL at epoch  8  is:  0.5600000023841858
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  8  is:  0.5600000023841858
#
# 200/200 [==============================] - 10s 48ms/step - loss: 0.6689 - binary_accuracy: 0.5750 - val_loss: 0.6770 - val_binary_accuracy: 0.5700
# Run:  3 / Accuracy on test ORIGINAL at epoch  9  is:  0.5699999928474426
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  9  is:  0.5899999737739563
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.6403 - binary_accuracy: 0.6350 - val_loss: 0.6678 - val_binary_accuracy: 0.5700
# Run:  3 / Accuracy on test ORIGINAL at epoch  10  is:  0.5699999928474426
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  10  is:  0.6000000238418579
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.5917 - binary_accuracy: 0.7150 - val_loss: 0.6570 - val_binary_accuracy: 0.5600
# Run:  3 / Accuracy on test ORIGINAL at epoch  11  is:  0.5600000023841858
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  11  is:  0.5899999737739563
#
# 200/200 [==============================] - 10s 51ms/step - loss: 0.5342 - binary_accuracy: 0.7850 - val_loss: 0.6537 - val_binary_accuracy: 0.5700
# Run:  3 / Accuracy on test ORIGINAL at epoch  12  is:  0.5699999928474426
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  12  is:  0.6499999761581421
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.4134 - binary_accuracy: 0.8400 - val_loss: 0.9286 - val_binary_accuracy: 0.5500
# Run:  3 / Accuracy on test ORIGINAL at epoch  13  is:  0.550000011920929
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  13  is:  0.6600000262260437
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.2860 - binary_accuracy: 0.8800 - val_loss: 1.4256 - val_binary_accuracy: 0.5300
# Run:  3 / Accuracy on test ORIGINAL at epoch  14  is:  0.5299999713897705
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  14  is:  0.6399999856948853
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.2169 - binary_accuracy: 0.8950 - val_loss: 1.7256 - val_binary_accuracy: 0.5300
# Run:  3 / Accuracy on test ORIGINAL at epoch  15  is:  0.5299999713897705
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  15  is:  0.6499999761581421
#
# 200/200 [==============================] - 11s 54ms/step - loss: 0.1335 - binary_accuracy: 0.9500 - val_loss: 2.2052 - val_binary_accuracy: 0.5300
# Run:  3 / Accuracy on test ORIGINAL at epoch  16  is:  0.5299999713897705
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  16  is:  0.6600000262260437
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.0836 - binary_accuracy: 0.9750 - val_loss: 2.1913 - val_binary_accuracy: 0.5700
# Run:  3 / Accuracy on test ORIGINAL at epoch  17  is:  0.5699999928474426
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  17  is:  0.6000000238418579
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.0187 - binary_accuracy: 1.0000 - val_loss: 4.1213 - val_binary_accuracy: 0.5100
# Run:  3 / Accuracy on test ORIGINAL at epoch  18  is:  0.5099999904632568
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  18  is:  0.6700000166893005
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.0081 - binary_accuracy: 1.0000 - val_loss: 5.6395 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  19  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  19  is:  0.6600000262260437
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5299999713897705, 0.5600000023841858, 0.5699999928474426, 0.5699999928474426, 0.5600000023841858, 0.5699999928474426, 0.550000011920929, 0.5299999713897705, 0.5299999713897705, 0.5299999713897705, 0.5699999928474426, 0.5099999904632568, 0.5]
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5199999809265137, 0.5600000023841858, 0.5899999737739563, 0.6000000238418579, 0.5899999737739563, 0.6499999761581421, 0.6600000262260437, 0.6399999856948853, 0.6499999761581421, 0.6600000262260437, 0.6000000238418579, 0.6700000166893005, 0.6600000262260437]
#
#
# 200/200 [==============================] - 36s 172ms/step - loss: 0.7057 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.6965 - binary_accuracy: 0.4000 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.6952 - binary_accuracy: 0.4200 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6948 - binary_accuracy: 0.4450 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6946 - binary_accuracy: 0.4050 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.6945 - binary_accuracy: 0.4150 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6944 - binary_accuracy: 0.4100 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  6  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6942 - binary_accuracy: 0.4400 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  7  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  7  is:  0.5
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.6937 - binary_accuracy: 0.4750 - val_loss: 0.6925 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  8  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  8  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6912 - binary_accuracy: 0.5100 - val_loss: 0.6893 - val_binary_accuracy: 0.5500
# Run:  4 / Accuracy on test ORIGINAL at epoch  9  is:  0.550000011920929
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  9  is:  0.5299999713897705
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6807 - binary_accuracy: 0.5550 - val_loss: 0.6812 - val_binary_accuracy: 0.5400
# Run:  4 / Accuracy on test ORIGINAL at epoch  10  is:  0.5400000214576721
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  10  is:  0.550000011920929
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6579 - binary_accuracy: 0.6050 - val_loss: 0.6726 - val_binary_accuracy: 0.5800
# Run:  4 / Accuracy on test ORIGINAL at epoch  11  is:  0.5799999833106995
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  11  is:  0.6000000238418579
#
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6267 - binary_accuracy: 0.6700 - val_loss: 0.6633 - val_binary_accuracy: 0.5700
# Run:  4 / Accuracy on test ORIGINAL at epoch  12  is:  0.5699999928474426
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  12  is:  0.6100000143051147
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.5717 - binary_accuracy: 0.7400 - val_loss: 0.6534 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test ORIGINAL at epoch  13  is:  0.6100000143051147
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  13  is:  0.6200000047683716
#
# 200/200 [==============================] - 11s 57ms/step - loss: 0.4953 - binary_accuracy: 0.8150 - val_loss: 0.6660 - val_binary_accuracy: 0.5600
# Run:  4 / Accuracy on test ORIGINAL at epoch  14  is:  0.5600000023841858
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  14  is:  0.6299999952316284
#
# 200/200 [==============================] - 11s 54ms/step - loss: 0.3760 - binary_accuracy: 0.8550 - val_loss: 1.0996 - val_binary_accuracy: 0.5400
# Run:  4 / Accuracy on test ORIGINAL at epoch  15  is:  0.5400000214576721
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  15  is:  0.6499999761581421
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.2708 - binary_accuracy: 0.8800 - val_loss: 1.5034 - val_binary_accuracy: 0.5300
# Run:  4 / Accuracy on test ORIGINAL at epoch  16  is:  0.5299999713897705
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  16  is:  0.6299999952316284
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.1856 - binary_accuracy: 0.9100 - val_loss: 2.1403 - val_binary_accuracy: 0.5100
# Run:  4 / Accuracy on test ORIGINAL at epoch  17  is:  0.5099999904632568
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  17  is:  0.6399999856948853
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.0922 - binary_accuracy: 0.9650 - val_loss: 1.9173 - val_binary_accuracy: 0.5600
# Run:  4 / Accuracy on test ORIGINAL at epoch  18  is:  0.5600000023841858
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  18  is:  0.6100000143051147
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.0643 - binary_accuracy: 0.9800 - val_loss: 2.5705 - val_binary_accuracy: 0.5400
# Run:  4 / Accuracy on test ORIGINAL at epoch  19  is:  0.5400000214576721
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  19  is:  0.6499999761581421
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.550000011920929, 0.5400000214576721, 0.5799999833106995, 0.5699999928474426, 0.6100000143051147, 0.5600000023841858, 0.5400000214576721, 0.5299999713897705, 0.5099999904632568, 0.5600000023841858, 0.5400000214576721]
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5299999713897705, 0.550000011920929, 0.6000000238418579, 0.6100000143051147, 0.6200000047683716, 0.6299999952316284, 0.6499999761581421, 0.6299999952316284, 0.6399999856948853, 0.6100000143051147, 0.6499999761581421]
#
#
# 200/200 [==============================] - 36s 172ms/step - loss: 0.7054 - binary_accuracy: 0.4450 - val_loss: 0.6933 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6964 - binary_accuracy: 0.4400 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  1  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6954 - binary_accuracy: 0.4150 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  2  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  2  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6952 - binary_accuracy: 0.4200 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  3  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  3  is:  0.5
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.6947 - binary_accuracy: 0.4200 - val_loss: 0.6932 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  4  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  4  is:  0.5
#
# 200/200 [==============================] - 11s 54ms/step - loss: 0.6944 - binary_accuracy: 0.4700 - val_loss: 0.6931 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  5  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  5  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6942 - binary_accuracy: 0.4650 - val_loss: 0.6926 - val_binary_accuracy: 0.5800
# Run:  5 / Accuracy on test ORIGINAL at epoch  6  is:  0.5799999833106995
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  6  is:  0.5
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6892 - binary_accuracy: 0.5200 - val_loss: 0.6886 - val_binary_accuracy: 0.5400
# Run:  5 / Accuracy on test ORIGINAL at epoch  7  is:  0.5400000214576721
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  7  is:  0.5600000023841858
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6752 - binary_accuracy: 0.5650 - val_loss: 0.6810 - val_binary_accuracy: 0.5300
# Run:  5 / Accuracy on test ORIGINAL at epoch  8  is:  0.5299999713897705
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  8  is:  0.5899999737739563
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6527 - binary_accuracy: 0.6300 - val_loss: 0.6735 - val_binary_accuracy: 0.5500
# Run:  5 / Accuracy on test ORIGINAL at epoch  9  is:  0.550000011920929
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  9  is:  0.6100000143051147
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.6133 - binary_accuracy: 0.6950 - val_loss: 0.6641 - val_binary_accuracy: 0.5600
# Run:  5 / Accuracy on test ORIGINAL at epoch  10  is:  0.5600000023841858
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  10  is:  0.6200000047683716
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.5514 - binary_accuracy: 0.7750 - val_loss: 0.6657 - val_binary_accuracy: 0.5600
# Run:  5 / Accuracy on test ORIGINAL at epoch  11  is:  0.5600000023841858
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  11  is:  0.6299999952316284
#
# 200/200 [==============================] - 10s 50ms/step - loss: 0.4546 - binary_accuracy: 0.8250 - val_loss: 0.9066 - val_binary_accuracy: 0.5200
# Run:  5 / Accuracy on test ORIGINAL at epoch  12  is:  0.5199999809265137
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  12  is:  0.6399999856948853
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.3246 - binary_accuracy: 0.8650 - val_loss: 1.4123 - val_binary_accuracy: 0.5100
# Run:  5 / Accuracy on test ORIGINAL at epoch  13  is:  0.5099999904632568
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  13  is:  0.6700000166893005
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.2054 - binary_accuracy: 0.9250 - val_loss: 2.4090 - val_binary_accuracy: 0.5100
# Run:  5 / Accuracy on test ORIGINAL at epoch  14  is:  0.5099999904632568
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  14  is:  0.6499999761581421
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.1356 - binary_accuracy: 0.9450 - val_loss: 2.4836 - val_binary_accuracy: 0.5100
# Run:  5 / Accuracy on test ORIGINAL at epoch  15  is:  0.5099999904632568
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  15  is:  0.6600000262260437
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.0801 - binary_accuracy: 0.9600 - val_loss: 3.5899 - val_binary_accuracy: 0.5100
# Run:  5 / Accuracy on test ORIGINAL at epoch  16  is:  0.5099999904632568
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  16  is:  0.6000000238418579
#
# 200/200 [==============================] - 10s 52ms/step - loss: 0.0481 - binary_accuracy: 0.9800 - val_loss: 4.1799 - val_binary_accuracy: 0.5100
# Run:  5 / Accuracy on test ORIGINAL at epoch  17  is:  0.5099999904632568
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  17  is:  0.6499999761581421
#
# 200/200 [==============================] - 11s 53ms/step - loss: 0.0161 - binary_accuracy: 0.9900 - val_loss: 2.9992 - val_binary_accuracy: 0.5300
# Run:  5 / Accuracy on test ORIGINAL at epoch  18  is:  0.5299999713897705
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  18  is:  0.6000000238418579
#
# 200/200 [==============================] - 10s 49ms/step - loss: 0.0085 - binary_accuracy: 1.0000 - val_loss: 8.2541 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  19  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  19  is:  0.6000000238418579
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5799999833106995, 0.5400000214576721, 0.5299999713897705, 0.550000011920929, 0.5600000023841858, 0.5600000023841858, 0.5199999809265137, 0.5099999904632568, 0.5099999904632568, 0.5099999904632568, 0.5099999904632568, 0.5099999904632568, 0.5299999713897705, 0.5]
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5600000023841858, 0.5899999737739563, 0.6100000143051147, 0.6200000047683716, 0.6299999952316284, 0.6399999856948853, 0.6700000166893005, 0.6499999761581421, 0.6600000262260437, 0.6000000238418579, 0.6499999761581421, 0.6000000238418579, 0.6000000238418579]
#
#
#
#
#  Over all runs maximum accuracies on ORIGINAL test set are: [0.5699999928474426, 0.5699999928474426, 0.5799999833106995, 0.5899999737739563, 0.6100000143051147]
# The median for English is: 0.5799999833106995
#
#
#
#
#
#  Over all runs maximum accuracies on AUGMENTED test set are: [0.6499999761581421, 0.6600000262260437, 0.6700000166893005, 0.6700000166893005, 0.6700000166893005]
# The median for English is: 0.6700000166893005
#
#
#
# CNN Accuracy Score on Original Test set ->  0.5799999833106995 +/- 0.030000030994415283
# CNN Accuracy Score on AUGMENTED Test set ->  0.6700000166893005 +/- 0.020000040531158447
