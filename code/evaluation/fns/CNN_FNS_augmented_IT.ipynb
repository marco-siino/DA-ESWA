# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/DA-ESWA/blob/main/code/evaluation/fns/CNN_FNS_augmented_IT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Investigating text data augmentation using back translation for author profiling
# - - -
# CNN ON HSS DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Fake News Spreaders Dataset augmented with IT backtranslation.
# Code by M. Siino.
#
# From the paper: "Investigating text data augmentation using back translation for author profiling" by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf

import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

os.environ['TF_CUDNN_DETERMINISTIC']='true'
os.environ['TF_DETERMINISTIC_OPS']='true'

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
urlTrainingSet = "https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-training-augmented-it.zip"
training_set = tf.keras.utils.get_file("pan20-author-profiling-training-2020-02-23-augmented.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSet="https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-original.zip"
test_set = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSetAug="https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-augmented-it.zip"
test_set_aug = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23-augmented.zip", urlTestSetAug,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
# Out:
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-training-augmented-it.zip
# 1707487/1707487 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-original.zip
# 864693/864693 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-augmented-it.zip
# 1142148/1142148 [==============================] - 0s 0us/step

# %%
training_set_dir = os.path.join(os.path.dirname(training_set), 'pan20-author-profiling-training-2020-02-23-augmented')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan20-author-profiling-test-2020-02-23')
test_set_aug_dir = os.path.join(os.path.dirname(test_set_aug), 'pan20-author-profiling-test-2020-02-23-augmented')

# !ls -A
# Out:
# .config
# pan20-author-profiling-test-2020-02-23
# pan20-author-profiling-test-2020-02-23-augmented
# pan20-author-profiling-test-2020-02-23-augmented.zip
# pan20-author-profiling-test-2020-02-23.zip
# pan20-author-profiling-training-2020-02-23-augmented
# pan20-author-profiling-training-2020-02-23-augmented.zip
# sample_data

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')

# Make Py variables.
test_dir='test_dir_'

## Test Augmented Folders. ##
# First level directory.
if not os.path.exists('test_aug_dir_en'):
    os.makedirs('test_aug_dir_en')

# Class labels directory.
if not os.path.exists('test_aug_dir_en/0'):
    os.makedirs('test_aug_dir_en/0')
if not os.path.exists('test_aug_dir_en/1'):
    os.makedirs('test_aug_dir_en/1')

# Make Py variables.
test_aug_dir='test_aug_dir_'

# !ls -A
# Out:
# .config
# pan20-author-profiling-test-2020-02-23
# pan20-author-profiling-test-2020-02-23-augmented
# pan20-author-profiling-test-2020-02-23-augmented.zip
# pan20-author-profiling-test-2020-02-23.zip
# pan20-author-profiling-training-2020-02-23-augmented
# pan20-author-profiling-training-2020-02-23-augmented.zip
# sample_data
# test_aug_dir_en
# test_dir_en
# train_dir_en

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es ground truth file path for train_dir. 
language='en'

truth_file_training_dir_en=training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_en = truth_file_test_dir+'/'+'truth'+'.txt'

truth_file_test_aug_dir=test_set_aug_dir
truth_file_test_aug_path_en = truth_file_test_aug_dir+'/'+'truth'+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training and test dataset folders.

# %%
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_aug_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_aug_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_aug_dir+'/'+language+'/'+fNameXml, './test_aug_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Generate full dataset.

# %%
# Generate full randomized training set.
batch_size=1

en_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_aug_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_aug_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

train_ds=en_train_ds.shuffle(300,seed=1, reshuffle_each_iteration=False)
test_ds=en_test_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)
test_aug_ds=en_test_aug_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
test_aug_ds_size=len(test_aug_ds)
# Out:
# Found 300 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text.

# %%
# Preprocessing function to remove some noise due to the translation.
def clean_samples(input_data):
  tag_author_lang_en_removed = tf.strings.regex_replace(input_data,'<author lang="en">', '')
  tag_opening_document_miscased = tf.strings.regex_replace(tag_author_lang_en_removed,'<Document>', '<document>')
  tag_closing_document_miscased = tf.strings.regex_replace(tag_opening_document_miscased,'</Document>', '</document>')
  tag_opening_documents = tf.strings.regex_replace(tag_closing_document_miscased,'<documents>', '')
  tag_opening_cdata_removed = tf.strings.regex_replace(tag_opening_documents,'<\!\[CDATA\[', ' ')
  tag_closing_cdata_removed = tf.strings.regex_replace(tag_opening_cdata_removed,'\]\]>', ' >')
  output_data = tf.strings.regex_replace(tag_closing_cdata_removed,'</documents>', '')
  return output_data

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 20000
  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

#opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Vectorization

# %%
print("\n\n* * * * VECTORIZATION STARTED * * * *")

# Preprocess training set to build a dictionary.
vectorize_layer = preprocess_and_adapt_ts(train_ds)

max_features=len(vectorize_layer.get_vocabulary()) + 1
print("Vocabulary size is:", max_features)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# * * * * VECTORIZATION STARTED * * * *
# Length of the longest sample is: 4801
# Vocabulary size is: 80502

# %% [markdown]
# ## Models definition, training and evaluation on original and on augmented test set.

# %%
tf.random.set_seed(1)

runs_accuracy = []
aug_runs_accuracy = []

for run in range(1,(num_runs+1)):
    epochs_accuracy = []
    aug_epochs_accuracy = []
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Conv1D(256,16,activation='relu'),
                                    layers.MaxPooling1D(),
                                    layers.Dropout(0.6),

                                    layers.Dense(512,activation='relu'),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer='RMSprop', metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        aug_score = model.evaluate(test_aug_ds, verbose=0)
        aug_accuracy = aug_score[1]
        print("Run: ",run,"/ Accuracy on test ORIGINAL at epoch ",epoch," is: ", accuracy[0],"\n")
        print("Run: ",run,"/ Accuracy on test AUGMENTED at epoch ",epoch," is: ", aug_accuracy,"\n")
        epochs_accuracy.append(accuracy[0])
        aug_epochs_accuracy.append(aug_accuracy)

    print("Accuracies on ORIGINAL over epochs:",epochs_accuracy,"\n")
    runs_accuracy.append(max(epochs_accuracy))
    print("Accuracies on AUGMENTED over epochs:",aug_epochs_accuracy,"\n\n")
    aug_runs_accuracy.append(max(aug_epochs_accuracy))

runs_accuracy.sort()
aug_runs_accuracy.sort()
print("\n\n Over all runs maximum accuracies on ORIGINAL test set are:", runs_accuracy)
print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
print("\n\n Over all runs maximum accuracies on AUGMENTED test set are:", aug_runs_accuracy)
print("The median for English is:",aug_runs_accuracy[2],"\n\n\n")

# Final Result on Original Test set
if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
  max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
else:
  max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on Original Test set -> ",final_result)

# Final result on AUGMENTED test set.
if (aug_runs_accuracy[2]-aug_runs_accuracy[0])>(aug_runs_accuracy[4]-aug_runs_accuracy[2]):
  max_range_from_median = aug_runs_accuracy[2]-aug_runs_accuracy[0]
else:
  max_range_from_median = aug_runs_accuracy[4]-aug_runs_accuracy[2]
final_result = str(aug_runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on AUGMENTED Test set -> ",final_result)
# Out:
# 300/300 [==============================] - 69s 200ms/step - loss: 0.7139 - binary_accuracy: 0.4833 - val_loss: 0.6930 - val_binary_accuracy: 0.5150
# Run:  1 / Accuracy on test ORIGINAL at epoch  0  is:  0.5149999856948853
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  0  is:  0.6000000238418579
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.6890 - binary_accuracy: 0.5633 - val_loss: 0.6904 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  1  is:  0.5799999833106995
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.5722 - binary_accuracy: 0.7500 - val_loss: 0.6547 - val_binary_accuracy: 0.5950
# Run:  1 / Accuracy on test ORIGINAL at epoch  2  is:  0.5950000286102295
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  2  is:  0.6700000166893005
#
# 300/300 [==============================] - 12s 42ms/step - loss: 0.3901 - binary_accuracy: 0.8333 - val_loss: 0.6272 - val_binary_accuracy: 0.6600
# Run:  1 / Accuracy on test ORIGINAL at epoch  3  is:  0.6600000262260437
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  3  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.2390 - binary_accuracy: 0.9167 - val_loss: 0.6223 - val_binary_accuracy: 0.6800
# Run:  1 / Accuracy on test ORIGINAL at epoch  4  is:  0.6800000071525574
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  4  is:  0.699999988079071
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.1352 - binary_accuracy: 0.9433 - val_loss: 0.6567 - val_binary_accuracy: 0.6550
# Run:  1 / Accuracy on test ORIGINAL at epoch  5  is:  0.6549999713897705
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  5  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0678 - binary_accuracy: 0.9667 - val_loss: 0.7984 - val_binary_accuracy: 0.6350
# Run:  1 / Accuracy on test ORIGINAL at epoch  6  is:  0.6349999904632568
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  6  is:  0.6299999952316284
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0548 - binary_accuracy: 0.9800 - val_loss: 0.7475 - val_binary_accuracy: 0.6650
# Run:  1 / Accuracy on test ORIGINAL at epoch  7  is:  0.6650000214576721
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  7  is:  0.675000011920929
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0496 - binary_accuracy: 0.9800 - val_loss: 0.7469 - val_binary_accuracy: 0.6700
# Run:  1 / Accuracy on test ORIGINAL at epoch  8  is:  0.6700000166893005
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  8  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0436 - binary_accuracy: 0.9900 - val_loss: 0.7865 - val_binary_accuracy: 0.6600
# Run:  1 / Accuracy on test ORIGINAL at epoch  9  is:  0.6600000262260437
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  9  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0390 - binary_accuracy: 0.9933 - val_loss: 0.8830 - val_binary_accuracy: 0.6650
# Run:  1 / Accuracy on test ORIGINAL at epoch  10  is:  0.6650000214576721
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  10  is:  0.699999988079071
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0321 - binary_accuracy: 0.9900 - val_loss: 0.8291 - val_binary_accuracy: 0.6650
# Run:  1 / Accuracy on test ORIGINAL at epoch  11  is:  0.6650000214576721
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  11  is:  0.6650000214576721
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0333 - binary_accuracy: 0.9933 - val_loss: 0.9314 - val_binary_accuracy: 0.6500
# Run:  1 / Accuracy on test ORIGINAL at epoch  12  is:  0.6499999761581421
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  12  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0364 - binary_accuracy: 0.9933 - val_loss: 0.9424 - val_binary_accuracy: 0.6450
# Run:  1 / Accuracy on test ORIGINAL at epoch  13  is:  0.6449999809265137
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  13  is:  0.6949999928474426
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0283 - binary_accuracy: 0.9967 - val_loss: 1.0227 - val_binary_accuracy: 0.6450
# Run:  1 / Accuracy on test ORIGINAL at epoch  14  is:  0.6449999809265137
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  14  is:  0.699999988079071
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0366 - binary_accuracy: 0.9933 - val_loss: 1.1172 - val_binary_accuracy: 0.6200
# Run:  1 / Accuracy on test ORIGINAL at epoch  15  is:  0.6200000047683716
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  15  is:  0.699999988079071
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0219 - binary_accuracy: 0.9933 - val_loss: 1.1660 - val_binary_accuracy: 0.6200
# Run:  1 / Accuracy on test ORIGINAL at epoch  16  is:  0.6200000047683716
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  16  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0490 - binary_accuracy: 0.9933 - val_loss: 1.0717 - val_binary_accuracy: 0.6200
# Run:  1 / Accuracy on test ORIGINAL at epoch  17  is:  0.6200000047683716
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  17  is:  0.7049999833106995
#
# 300/300 [==============================] - 13s 42ms/step - loss: 0.0294 - binary_accuracy: 0.9967 - val_loss: 1.2327 - val_binary_accuracy: 0.6050
# Run:  1 / Accuracy on test ORIGINAL at epoch  18  is:  0.6050000190734863
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  18  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0304 - binary_accuracy: 0.9933 - val_loss: 1.2393 - val_binary_accuracy: 0.6150
# Run:  1 / Accuracy on test ORIGINAL at epoch  19  is:  0.6150000095367432
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  19  is:  0.7049999833106995
#
# Accuracies on ORIGINAL over epochs: [0.5149999856948853, 0.5, 0.5950000286102295, 0.6600000262260437, 0.6800000071525574, 0.6549999713897705, 0.6349999904632568, 0.6650000214576721, 0.6700000166893005, 0.6600000262260437, 0.6650000214576721, 0.6650000214576721, 0.6499999761581421, 0.6449999809265137, 0.6449999809265137, 0.6200000047683716, 0.6200000047683716, 0.6200000047683716, 0.6050000190734863, 0.6150000095367432]
#
# Accuracies on AUGMENTED over epochs: [0.6000000238418579, 0.5799999833106995, 0.6700000166893005, 0.6899999976158142, 0.699999988079071, 0.6899999976158142, 0.6299999952316284, 0.675000011920929, 0.6800000071525574, 0.7049999833106995, 0.699999988079071, 0.6650000214576721, 0.6899999976158142, 0.6949999928474426, 0.699999988079071, 0.699999988079071, 0.7049999833106995, 0.7049999833106995, 0.7049999833106995, 0.7049999833106995]
#
#
# 300/300 [==============================] - 47s 151ms/step - loss: 0.7107 - binary_accuracy: 0.4800 - val_loss: 0.6930 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  0  is:  0.5600000023841858
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.6895 - binary_accuracy: 0.5600 - val_loss: 0.6897 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  1  is:  0.5600000023841858
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.5891 - binary_accuracy: 0.7400 - val_loss: 0.6542 - val_binary_accuracy: 0.5900
# Run:  2 / Accuracy on test ORIGINAL at epoch  2  is:  0.5899999737739563
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  2  is:  0.6349999904632568
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.4408 - binary_accuracy: 0.8300 - val_loss: 0.8187 - val_binary_accuracy: 0.5250
# Run:  2 / Accuracy on test ORIGINAL at epoch  3  is:  0.5249999761581421
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  3  is:  0.6700000166893005
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.2810 - binary_accuracy: 0.9000 - val_loss: 0.7585 - val_binary_accuracy: 0.5850
# Run:  2 / Accuracy on test ORIGINAL at epoch  4  is:  0.5849999785423279
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  4  is:  0.675000011920929
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.1611 - binary_accuracy: 0.9300 - val_loss: 0.8029 - val_binary_accuracy: 0.6000
# Run:  2 / Accuracy on test ORIGINAL at epoch  5  is:  0.6000000238418579
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  5  is:  0.6499999761581421
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0983 - binary_accuracy: 0.9733 - val_loss: 0.8936 - val_binary_accuracy: 0.5750
# Run:  2 / Accuracy on test ORIGINAL at epoch  6  is:  0.574999988079071
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  6  is:  0.6299999952316284
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0705 - binary_accuracy: 0.9800 - val_loss: 0.8376 - val_binary_accuracy: 0.6150
# Run:  2 / Accuracy on test ORIGINAL at epoch  7  is:  0.6150000095367432
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  7  is:  0.6650000214576721
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0522 - binary_accuracy: 0.9800 - val_loss: 1.0789 - val_binary_accuracy: 0.5650
# Run:  2 / Accuracy on test ORIGINAL at epoch  8  is:  0.5649999976158142
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  8  is:  0.6349999904632568
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0415 - binary_accuracy: 0.9900 - val_loss: 0.8472 - val_binary_accuracy: 0.6450
# Run:  2 / Accuracy on test ORIGINAL at epoch  9  is:  0.6449999809265137
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  9  is:  0.6650000214576721
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0422 - binary_accuracy: 0.9900 - val_loss: 1.0269 - val_binary_accuracy: 0.5950
# Run:  2 / Accuracy on test ORIGINAL at epoch  10  is:  0.5950000286102295
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  10  is:  0.675000011920929
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0206 - binary_accuracy: 0.9933 - val_loss: 0.8739 - val_binary_accuracy: 0.6300
# Run:  2 / Accuracy on test ORIGINAL at epoch  11  is:  0.6299999952316284
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  11  is:  0.6949999928474426
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0230 - binary_accuracy: 0.9967 - val_loss: 0.8809 - val_binary_accuracy: 0.6500
# Run:  2 / Accuracy on test ORIGINAL at epoch  12  is:  0.6499999761581421
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  12  is:  0.6850000023841858
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0328 - binary_accuracy: 0.9900 - val_loss: 0.8706 - val_binary_accuracy: 0.6400
# Run:  2 / Accuracy on test ORIGINAL at epoch  13  is:  0.6399999856948853
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  13  is:  0.6850000023841858
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0307 - binary_accuracy: 0.9967 - val_loss: 0.9234 - val_binary_accuracy: 0.6450
# Run:  2 / Accuracy on test ORIGINAL at epoch  14  is:  0.6449999809265137
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  14  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0200 - binary_accuracy: 0.9933 - val_loss: 0.8987 - val_binary_accuracy: 0.6550
# Run:  2 / Accuracy on test ORIGINAL at epoch  15  is:  0.6549999713897705
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  15  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0420 - binary_accuracy: 0.9933 - val_loss: 0.9013 - val_binary_accuracy: 0.6750
# Run:  2 / Accuracy on test ORIGINAL at epoch  16  is:  0.675000011920929
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  16  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0331 - binary_accuracy: 0.9933 - val_loss: 0.9065 - val_binary_accuracy: 0.6500
# Run:  2 / Accuracy on test ORIGINAL at epoch  17  is:  0.6499999761581421
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  17  is:  0.6949999928474426
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0199 - binary_accuracy: 0.9933 - val_loss: 0.9179 - val_binary_accuracy: 0.6650
# Run:  2 / Accuracy on test ORIGINAL at epoch  18  is:  0.6650000214576721
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  18  is:  0.7149999737739563
#
# 300/300 [==============================] - 13s 43ms/step - loss: 0.0482 - binary_accuracy: 0.9933 - val_loss: 0.9587 - val_binary_accuracy: 0.6500
# Run:  2 / Accuracy on test ORIGINAL at epoch  19  is:  0.6499999761581421
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  19  is:  0.6850000023841858
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5899999737739563, 0.5249999761581421, 0.5849999785423279, 0.6000000238418579, 0.574999988079071, 0.6150000095367432, 0.5649999976158142, 0.6449999809265137, 0.5950000286102295, 0.6299999952316284, 0.6499999761581421, 0.6399999856948853, 0.6449999809265137, 0.6549999713897705, 0.675000011920929, 0.6499999761581421, 0.6650000214576721, 0.6499999761581421]
#
# Accuracies on AUGMENTED over epochs: [0.5600000023841858, 0.5600000023841858, 0.6349999904632568, 0.6700000166893005, 0.675000011920929, 0.6499999761581421, 0.6299999952316284, 0.6650000214576721, 0.6349999904632568, 0.6650000214576721, 0.675000011920929, 0.6949999928474426, 0.6850000023841858, 0.6850000023841858, 0.6899999976158142, 0.6899999976158142, 0.6800000071525574, 0.6949999928474426, 0.7149999737739563, 0.6850000023841858]
#
#
# 300/300 [==============================] - 45s 147ms/step - loss: 0.7112 - binary_accuracy: 0.4700 - val_loss: 0.6929 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  0  is:  0.5450000166893005
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.6909 - binary_accuracy: 0.5500 - val_loss: 0.6792 - val_binary_accuracy: 0.5650
# Run:  3 / Accuracy on test ORIGINAL at epoch  1  is:  0.5649999976158142
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  1  is:  0.574999988079071
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.5870 - binary_accuracy: 0.7200 - val_loss: 0.6519 - val_binary_accuracy: 0.6000
# Run:  3 / Accuracy on test ORIGINAL at epoch  2  is:  0.6000000238418579
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  2  is:  0.6549999713897705
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.4243 - binary_accuracy: 0.8300 - val_loss: 0.6880 - val_binary_accuracy: 0.5750
# Run:  3 / Accuracy on test ORIGINAL at epoch  3  is:  0.574999988079071
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  3  is:  0.6600000262260437
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.2661 - binary_accuracy: 0.9067 - val_loss: 0.8166 - val_binary_accuracy: 0.5350
# Run:  3 / Accuracy on test ORIGINAL at epoch  4  is:  0.5350000262260437
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  4  is:  0.6650000214576721
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.1649 - binary_accuracy: 0.9300 - val_loss: 1.0265 - val_binary_accuracy: 0.5100
# Run:  3 / Accuracy on test ORIGINAL at epoch  5  is:  0.5099999904632568
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  5  is:  0.6549999713897705
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0933 - binary_accuracy: 0.9700 - val_loss: 1.2281 - val_binary_accuracy: 0.5100
# Run:  3 / Accuracy on test ORIGINAL at epoch  6  is:  0.5099999904632568
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  6  is:  0.625
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0620 - binary_accuracy: 0.9767 - val_loss: 1.3562 - val_binary_accuracy: 0.5050
# Run:  3 / Accuracy on test ORIGINAL at epoch  7  is:  0.5049999952316284
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  7  is:  0.6100000143051147
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0497 - binary_accuracy: 0.9800 - val_loss: 1.2924 - val_binary_accuracy: 0.5400
# Run:  3 / Accuracy on test ORIGINAL at epoch  8  is:  0.5400000214576721
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  8  is:  0.6399999856948853
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0358 - binary_accuracy: 0.9900 - val_loss: 1.7607 - val_binary_accuracy: 0.5050
# Run:  3 / Accuracy on test ORIGINAL at epoch  9  is:  0.5049999952316284
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  9  is:  0.6200000047683716
#
# 300/300 [==============================] - 13s 42ms/step - loss: 0.0442 - binary_accuracy: 0.9900 - val_loss: 1.3139 - val_binary_accuracy: 0.5400
# Run:  3 / Accuracy on test ORIGINAL at epoch  10  is:  0.5400000214576721
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  10  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0240 - binary_accuracy: 0.9933 - val_loss: 1.5344 - val_binary_accuracy: 0.5350
# Run:  3 / Accuracy on test ORIGINAL at epoch  11  is:  0.5350000262260437
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  11  is:  0.6549999713897705
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0276 - binary_accuracy: 0.9967 - val_loss: 1.3870 - val_binary_accuracy: 0.5500
# Run:  3 / Accuracy on test ORIGINAL at epoch  12  is:  0.550000011920929
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  12  is:  0.6850000023841858
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0245 - binary_accuracy: 0.9933 - val_loss: 1.2991 - val_binary_accuracy: 0.5550
# Run:  3 / Accuracy on test ORIGINAL at epoch  13  is:  0.5550000071525574
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  13  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0452 - binary_accuracy: 0.9933 - val_loss: 1.5245 - val_binary_accuracy: 0.5400
# Run:  3 / Accuracy on test ORIGINAL at epoch  14  is:  0.5400000214576721
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  14  is:  0.675000011920929
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0231 - binary_accuracy: 0.9933 - val_loss: 1.3865 - val_binary_accuracy: 0.5600
# Run:  3 / Accuracy on test ORIGINAL at epoch  15  is:  0.5600000023841858
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  15  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0393 - binary_accuracy: 0.9933 - val_loss: 1.5107 - val_binary_accuracy: 0.5550
# Run:  3 / Accuracy on test ORIGINAL at epoch  16  is:  0.5550000071525574
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  16  is:  0.6700000166893005
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0344 - binary_accuracy: 0.9933 - val_loss: 1.2501 - val_binary_accuracy: 0.5950
# Run:  3 / Accuracy on test ORIGINAL at epoch  17  is:  0.5950000286102295
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  17  is:  0.7099999785423279
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0314 - binary_accuracy: 0.9967 - val_loss: 1.5782 - val_binary_accuracy: 0.5650
# Run:  3 / Accuracy on test ORIGINAL at epoch  18  is:  0.5649999976158142
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  18  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0318 - binary_accuracy: 0.9933 - val_loss: 1.3361 - val_binary_accuracy: 0.5950
# Run:  3 / Accuracy on test ORIGINAL at epoch  19  is:  0.5950000286102295
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  19  is:  0.7149999737739563
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5649999976158142, 0.6000000238418579, 0.574999988079071, 0.5350000262260437, 0.5099999904632568, 0.5099999904632568, 0.5049999952316284, 0.5400000214576721, 0.5049999952316284, 0.5400000214576721, 0.5350000262260437, 0.550000011920929, 0.5550000071525574, 0.5400000214576721, 0.5600000023841858, 0.5550000071525574, 0.5950000286102295, 0.5649999976158142, 0.5950000286102295]
#
# Accuracies on AUGMENTED over epochs: [0.5450000166893005, 0.574999988079071, 0.6549999713897705, 0.6600000262260437, 0.6650000214576721, 0.6549999713897705, 0.625, 0.6100000143051147, 0.6399999856948853, 0.6200000047683716, 0.6899999976158142, 0.6549999713897705, 0.6850000023841858, 0.6800000071525574, 0.675000011920929, 0.7049999833106995, 0.6700000166893005, 0.7099999785423279, 0.6899999976158142, 0.7149999737739563]
#
#
# 300/300 [==============================] - 46s 150ms/step - loss: 0.7122 - binary_accuracy: 0.5000 - val_loss: 0.6926 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  0  is:  0.574999988079071
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.6890 - binary_accuracy: 0.5733 - val_loss: 0.6680 - val_binary_accuracy: 0.6600
# Run:  4 / Accuracy on test ORIGINAL at epoch  1  is:  0.6600000262260437
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  1  is:  0.574999988079071
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.5777 - binary_accuracy: 0.7367 - val_loss: 0.6204 - val_binary_accuracy: 0.6550
# Run:  4 / Accuracy on test ORIGINAL at epoch  2  is:  0.6549999713897705
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  2  is:  0.6700000166893005
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.4158 - binary_accuracy: 0.8233 - val_loss: 0.6377 - val_binary_accuracy: 0.6300
# Run:  4 / Accuracy on test ORIGINAL at epoch  3  is:  0.6299999952316284
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  3  is:  0.6850000023841858
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.2622 - binary_accuracy: 0.9067 - val_loss: 0.7082 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test ORIGINAL at epoch  4  is:  0.6100000143051147
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  4  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.1417 - binary_accuracy: 0.9400 - val_loss: 0.8135 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test ORIGINAL at epoch  5  is:  0.6100000143051147
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  5  is:  0.699999988079071
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0828 - binary_accuracy: 0.9700 - val_loss: 0.7669 - val_binary_accuracy: 0.6450
# Run:  4 / Accuracy on test ORIGINAL at epoch  6  is:  0.6449999809265137
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  6  is:  0.6299999952316284
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0749 - binary_accuracy: 0.9767 - val_loss: 0.9088 - val_binary_accuracy: 0.6400
# Run:  4 / Accuracy on test ORIGINAL at epoch  7  is:  0.6399999856948853
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  7  is:  0.6700000166893005
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0438 - binary_accuracy: 0.9900 - val_loss: 1.2197 - val_binary_accuracy: 0.5800
# Run:  4 / Accuracy on test ORIGINAL at epoch  8  is:  0.5799999833106995
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  8  is:  0.6850000023841858
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0262 - binary_accuracy: 0.9933 - val_loss: 1.4784 - val_binary_accuracy: 0.5650
# Run:  4 / Accuracy on test ORIGINAL at epoch  9  is:  0.5649999976158142
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  9  is:  0.699999988079071
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0322 - binary_accuracy: 0.9933 - val_loss: 1.2679 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test ORIGINAL at epoch  10  is:  0.6100000143051147
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  10  is:  0.6549999713897705
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0314 - binary_accuracy: 0.9933 - val_loss: 1.2913 - val_binary_accuracy: 0.6200
# Run:  4 / Accuracy on test ORIGINAL at epoch  11  is:  0.6200000047683716
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  11  is:  0.6449999809265137
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0394 - binary_accuracy: 0.9900 - val_loss: 1.6743 - val_binary_accuracy: 0.5850
# Run:  4 / Accuracy on test ORIGINAL at epoch  12  is:  0.5849999785423279
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  12  is:  0.7200000286102295
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0381 - binary_accuracy: 0.9933 - val_loss: 1.7984 - val_binary_accuracy: 0.5800
# Run:  4 / Accuracy on test ORIGINAL at epoch  13  is:  0.5799999833106995
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  13  is:  0.7099999785423279
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0395 - binary_accuracy: 0.9933 - val_loss: 1.8146 - val_binary_accuracy: 0.5800
# Run:  4 / Accuracy on test ORIGINAL at epoch  14  is:  0.5799999833106995
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  14  is:  0.7099999785423279
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0362 - binary_accuracy: 0.9933 - val_loss: 2.1246 - val_binary_accuracy: 0.5200
# Run:  4 / Accuracy on test ORIGINAL at epoch  15  is:  0.5199999809265137
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  15  is:  0.675000011920929
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0332 - binary_accuracy: 0.9933 - val_loss: 2.2171 - val_binary_accuracy: 0.5300
# Run:  4 / Accuracy on test ORIGINAL at epoch  16  is:  0.5299999713897705
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  16  is:  0.6549999713897705
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0420 - binary_accuracy: 0.9933 - val_loss: 2.2139 - val_binary_accuracy: 0.5350
# Run:  4 / Accuracy on test ORIGINAL at epoch  17  is:  0.5350000262260437
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  17  is:  0.6600000262260437
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0402 - binary_accuracy: 0.9933 - val_loss: 2.1918 - val_binary_accuracy: 0.5300
# Run:  4 / Accuracy on test ORIGINAL at epoch  18  is:  0.5299999713897705
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  18  is:  0.6549999713897705
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0418 - binary_accuracy: 0.9933 - val_loss: 2.1915 - val_binary_accuracy: 0.5450
# Run:  4 / Accuracy on test ORIGINAL at epoch  19  is:  0.5450000166893005
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  19  is:  0.6549999713897705
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.6600000262260437, 0.6549999713897705, 0.6299999952316284, 0.6100000143051147, 0.6100000143051147, 0.6449999809265137, 0.6399999856948853, 0.5799999833106995, 0.5649999976158142, 0.6100000143051147, 0.6200000047683716, 0.5849999785423279, 0.5799999833106995, 0.5799999833106995, 0.5199999809265137, 0.5299999713897705, 0.5350000262260437, 0.5299999713897705, 0.5450000166893005]
#
# Accuracies on AUGMENTED over epochs: [0.574999988079071, 0.574999988079071, 0.6700000166893005, 0.6850000023841858, 0.7049999833106995, 0.699999988079071, 0.6299999952316284, 0.6700000166893005, 0.6850000023841858, 0.699999988079071, 0.6549999713897705, 0.6449999809265137, 0.7200000286102295, 0.7099999785423279, 0.7099999785423279, 0.675000011920929, 0.6549999713897705, 0.6600000262260437, 0.6549999713897705, 0.6549999713897705]
#
#
# 300/300 [==============================] - 47s 152ms/step - loss: 0.7111 - binary_accuracy: 0.4800 - val_loss: 0.6932 - val_binary_accuracy: 0.4850
# Run:  5 / Accuracy on test ORIGINAL at epoch  0  is:  0.48500001430511475
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.6983 - binary_accuracy: 0.5267 - val_loss: 0.6887 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  1  is:  0.6000000238418579
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.6195 - binary_accuracy: 0.6867 - val_loss: 0.6759 - val_binary_accuracy: 0.5250
# Run:  5 / Accuracy on test ORIGINAL at epoch  2  is:  0.5249999761581421
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  2  is:  0.6200000047683716
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.4589 - binary_accuracy: 0.8033 - val_loss: 0.6590 - val_binary_accuracy: 0.6200
# Run:  5 / Accuracy on test ORIGINAL at epoch  3  is:  0.6200000047683716
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  3  is:  0.6600000262260437
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.3096 - binary_accuracy: 0.8800 - val_loss: 0.7338 - val_binary_accuracy: 0.5950
# Run:  5 / Accuracy on test ORIGINAL at epoch  4  is:  0.5950000286102295
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  4  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.1862 - binary_accuracy: 0.9267 - val_loss: 0.7587 - val_binary_accuracy: 0.6050
# Run:  5 / Accuracy on test ORIGINAL at epoch  5  is:  0.6050000190734863
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  5  is:  0.6700000166893005
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.1088 - binary_accuracy: 0.9600 - val_loss: 1.0056 - val_binary_accuracy: 0.5550
# Run:  5 / Accuracy on test ORIGINAL at epoch  6  is:  0.5550000071525574
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  6  is:  0.625
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0655 - binary_accuracy: 0.9767 - val_loss: 0.9247 - val_binary_accuracy: 0.6050
# Run:  5 / Accuracy on test ORIGINAL at epoch  7  is:  0.6050000190734863
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  7  is:  0.6399999856948853
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0692 - binary_accuracy: 0.9800 - val_loss: 0.9926 - val_binary_accuracy: 0.5850
# Run:  5 / Accuracy on test ORIGINAL at epoch  8  is:  0.5849999785423279
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  8  is:  0.6549999713897705
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0531 - binary_accuracy: 0.9867 - val_loss: 0.9651 - val_binary_accuracy: 0.6100
# Run:  5 / Accuracy on test ORIGINAL at epoch  9  is:  0.6100000143051147
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  9  is:  0.6650000214576721
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0468 - binary_accuracy: 0.9900 - val_loss: 0.9204 - val_binary_accuracy: 0.6250
# Run:  5 / Accuracy on test ORIGINAL at epoch  10  is:  0.625
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  10  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0324 - binary_accuracy: 0.9933 - val_loss: 1.0318 - val_binary_accuracy: 0.6150
# Run:  5 / Accuracy on test ORIGINAL at epoch  11  is:  0.6150000095367432
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  11  is:  0.6650000214576721
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0480 - binary_accuracy: 0.9900 - val_loss: 1.0943 - val_binary_accuracy: 0.5950
# Run:  5 / Accuracy on test ORIGINAL at epoch  12  is:  0.5950000286102295
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  12  is:  0.675000011920929
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0409 - binary_accuracy: 0.9933 - val_loss: 1.2223 - val_binary_accuracy: 0.5850
# Run:  5 / Accuracy on test ORIGINAL at epoch  13  is:  0.5849999785423279
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  13  is:  0.675000011920929
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0293 - binary_accuracy: 0.9933 - val_loss: 1.0545 - val_binary_accuracy: 0.6250
# Run:  5 / Accuracy on test ORIGINAL at epoch  14  is:  0.625
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  14  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0310 - binary_accuracy: 0.9967 - val_loss: 1.1175 - val_binary_accuracy: 0.6250
# Run:  5 / Accuracy on test ORIGINAL at epoch  15  is:  0.625
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  15  is:  0.6899999976158142
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0167 - binary_accuracy: 0.9967 - val_loss: 1.4841 - val_binary_accuracy: 0.5750
# Run:  5 / Accuracy on test ORIGINAL at epoch  16  is:  0.574999988079071
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  16  is:  0.6000000238418579
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0204 - binary_accuracy: 0.9967 - val_loss: 1.0388 - val_binary_accuracy: 0.6450
# Run:  5 / Accuracy on test ORIGINAL at epoch  17  is:  0.6449999809265137
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  17  is:  0.6800000071525574
#
# 300/300 [==============================] - 13s 42ms/step - loss: 0.0290 - binary_accuracy: 0.9967 - val_loss: 1.3698 - val_binary_accuracy: 0.6100
# Run:  5 / Accuracy on test ORIGINAL at epoch  18  is:  0.6100000143051147
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  18  is:  0.6299999952316284
#
# 300/300 [==============================] - 12s 40ms/step - loss: 0.0213 - binary_accuracy: 0.9967 - val_loss: 1.3629 - val_binary_accuracy: 0.6000
# Run:  5 / Accuracy on test ORIGINAL at epoch  19  is:  0.6000000238418579
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  19  is:  0.6800000071525574
#
# Accuracies on ORIGINAL over epochs: [0.48500001430511475, 0.5, 0.5249999761581421, 0.6200000047683716, 0.5950000286102295, 0.6050000190734863, 0.5550000071525574, 0.6050000190734863, 0.5849999785423279, 0.6100000143051147, 0.625, 0.6150000095367432, 0.5950000286102295, 0.5849999785423279, 0.625, 0.625, 0.574999988079071, 0.6449999809265137, 0.6100000143051147, 0.6000000238418579]
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.6000000238418579, 0.6200000047683716, 0.6600000262260437, 0.6800000071525574, 0.6700000166893005, 0.625, 0.6399999856948853, 0.6549999713897705, 0.6650000214576721, 0.6899999976158142, 0.6650000214576721, 0.675000011920929, 0.675000011920929, 0.6800000071525574, 0.6899999976158142, 0.6000000238418579, 0.6800000071525574, 0.6299999952316284, 0.6800000071525574]
#
#
#
#
#  Over all runs maximum accuracies on ORIGINAL test set are: [0.6000000238418579, 0.6449999809265137, 0.6600000262260437, 0.675000011920929, 0.6800000071525574]
# The median for English is: 0.6600000262260437
#
#
#
#
#
#  Over all runs maximum accuracies on AUGMENTED test set are: [0.6899999976158142, 0.7049999833106995, 0.7149999737739563, 0.7149999737739563, 0.7200000286102295]
# The median for English is: 0.7149999737739563
#
#
#
# CNN Accuracy Score on Original Test set ->  0.6600000262260437 +/- 0.06000000238418579
# CNN Accuracy Score on AUGMENTED Test set ->  0.7149999737739563 +/- 0.02499997615814209
