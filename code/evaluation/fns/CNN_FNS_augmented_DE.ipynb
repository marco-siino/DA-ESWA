# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/DA-ESWA/blob/main/code/evaluation/fns/CNN_FNS_augmented_DE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Investigating text data augmentation using back translation for author profiling
# - - -
# CNN ON HSS DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Fake News Spreaders Dataset augmented with DE backtranslation.
# Code by M. Siino.
#
# From the paper: "Investigating text data augmentation using back translation for author profiling" by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf

import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

os.environ['TF_CUDNN_DETERMINISTIC']='true'
os.environ['TF_DETERMINISTIC_OPS']='true'

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
urlTrainingSet = "https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-training-augmented-de.zip"
training_set = tf.keras.utils.get_file("pan20-author-profiling-training-2020-02-23-augmented.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSet="https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-original.zip"
test_set = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSetAug="https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-augmented-de.zip"
test_set_aug = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23-augmented.zip", urlTestSetAug,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
# Out:
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-training-augmented-de.zip
# 1783406/1783406 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-original.zip
# 864693/864693 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-augmented-de.zip
# 1204983/1204983 [==============================] - 0s 0us/step

# %%
training_set_dir = os.path.join(os.path.dirname(training_set), 'pan20-author-profiling-training-2020-02-23-augmented')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan20-author-profiling-test-2020-02-23')
test_set_aug_dir = os.path.join(os.path.dirname(test_set_aug), 'pan20-author-profiling-test-2020-02-23-augmented')

# !ls -A
# Out:
# .config
# pan20-author-profiling-test-2020-02-23
# pan20-author-profiling-test-2020-02-23-augmented
# pan20-author-profiling-test-2020-02-23-augmented.zip
# pan20-author-profiling-test-2020-02-23.zip
# pan20-author-profiling-training-2020-02-23-augmented
# pan20-author-profiling-training-2020-02-23-augmented.zip
# sample_data

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')

# Make Py variables.
test_dir='test_dir_'

## Test Augmented Folders. ##
# First level directory.
if not os.path.exists('test_aug_dir_en'):
    os.makedirs('test_aug_dir_en')

# Class labels directory.
if not os.path.exists('test_aug_dir_en/0'):
    os.makedirs('test_aug_dir_en/0')
if not os.path.exists('test_aug_dir_en/1'):
    os.makedirs('test_aug_dir_en/1')

# Make Py variables.
test_aug_dir='test_aug_dir_'

# !ls -A
# Out:
# .config
# pan20-author-profiling-test-2020-02-23
# pan20-author-profiling-test-2020-02-23-augmented
# pan20-author-profiling-test-2020-02-23-augmented.zip
# pan20-author-profiling-test-2020-02-23.zip
# pan20-author-profiling-training-2020-02-23-augmented
# pan20-author-profiling-training-2020-02-23-augmented.zip
# sample_data
# test_aug_dir_en
# test_dir_en
# train_dir_en

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es ground truth file path for train_dir. 
language='en'

truth_file_training_dir_en=training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_en = truth_file_test_dir+'/'+'truth'+'.txt'

truth_file_test_aug_dir=test_set_aug_dir
truth_file_test_aug_path_en = truth_file_test_aug_dir+'/'+'truth'+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training and test dataset folders.

# %%
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_aug_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_aug_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_aug_dir+'/'+language+'/'+fNameXml, './test_aug_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Generate full dataset.

# %%
# Generate full randomized training set.
batch_size=1

en_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_aug_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_aug_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

train_ds=en_train_ds.shuffle(300,seed=1, reshuffle_each_iteration=False)
test_ds=en_test_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)
test_aug_ds=en_test_aug_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
test_aug_ds_size=len(test_aug_ds)
# Out:
# Found 300 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.
# Found 200 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text.

# %%
# Preprocessing function to remove some noise due to the translation.
def clean_samples(input_data):
  tag_author_lang_en_removed = tf.strings.regex_replace(input_data,'<author lang="en">', '')
  tag_opening_document_miscased = tf.strings.regex_replace(tag_author_lang_en_removed,'<Document>', '<document>')
  tag_closing_document_miscased = tf.strings.regex_replace(tag_opening_document_miscased,'</Document>', '</document>')
  tag_opening_documents = tf.strings.regex_replace(tag_closing_document_miscased,'<documents>', '')
  tag_opening_cdata_removed = tf.strings.regex_replace(tag_opening_documents,'<\!\[CDATA\[', ' ')
  tag_closing_cdata_removed = tf.strings.regex_replace(tag_opening_cdata_removed,'\]\]>', ' >')
  output_data = tf.strings.regex_replace(tag_closing_cdata_removed,'</documents>', '')
  return output_data

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 20000
  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

#opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Vectorization

# %%
print("\n\n* * * * VECTORIZATION STARTED * * * *")

# Preprocess training set to build a dictionary.
vectorize_layer = preprocess_and_adapt_ts(train_ds)

max_features=len(vectorize_layer.get_vocabulary()) + 1
print("Vocabulary size is:", max_features)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# * * * * VECTORIZATION STARTED * * * *
# Length of the longest sample is: 4787
# Vocabulary size is: 85866

# %% [markdown]
# ## Models definition, training and evaluation on original and on augmented test set.

# %%
tf.random.set_seed(1)

runs_accuracy = []
aug_runs_accuracy = []

for run in range(1,(num_runs+1)):
    epochs_accuracy = []
    aug_epochs_accuracy = []
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Conv1D(256,16,activation='relu'),
                                    layers.MaxPooling1D(),
                                    layers.Dropout(0.6),

                                    layers.Dense(512,activation='relu'),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer='RMSprop', metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        aug_score = model.evaluate(test_aug_ds, verbose=0)
        aug_accuracy = aug_score[1]
        print("Run: ",run,"/ Accuracy on test ORIGINAL at epoch ",epoch," is: ", accuracy[0],"\n")
        print("Run: ",run,"/ Accuracy on test AUGMENTED at epoch ",epoch," is: ", aug_accuracy,"\n")
        epochs_accuracy.append(accuracy[0])
        aug_epochs_accuracy.append(aug_accuracy)

    print("Accuracies on ORIGINAL over epochs:",epochs_accuracy,"\n")
    runs_accuracy.append(max(epochs_accuracy))
    print("Accuracies on AUGMENTED over epochs:",aug_epochs_accuracy,"\n\n")
    aug_runs_accuracy.append(max(aug_epochs_accuracy))

runs_accuracy.sort()
aug_runs_accuracy.sort()
print("\n\n Over all runs maximum accuracies on ORIGINAL test set are:", runs_accuracy)
print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
print("\n\n Over all runs maximum accuracies on AUGMENTED test set are:", aug_runs_accuracy)
print("The median for English is:",aug_runs_accuracy[2],"\n\n\n")

# Final Result on Original Test set
if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
  max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
else:
  max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on Original Test set -> ",final_result)

# Final result on AUGMENTED test set.
if (aug_runs_accuracy[2]-aug_runs_accuracy[0])>(aug_runs_accuracy[4]-aug_runs_accuracy[2]):
  max_range_from_median = aug_runs_accuracy[2]-aug_runs_accuracy[0]
else:
  max_range_from_median = aug_runs_accuracy[4]-aug_runs_accuracy[2]
final_result = str(aug_runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on AUGMENTED Test set -> ",final_result)
# Out:
# 300/300 [==============================] - 71s 203ms/step - loss: 0.7118 - binary_accuracy: 0.4967 - val_loss: 0.6930 - val_binary_accuracy: 0.5050
# Run:  1 / Accuracy on test ORIGINAL at epoch  0  is:  0.5049999952316284
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  0  is:  0.5799999833106995
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.6876 - binary_accuracy: 0.5600 - val_loss: 0.6972 - val_binary_accuracy: 0.5000
# Run:  1 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  1  is:  0.5400000214576721
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.5956 - binary_accuracy: 0.7200 - val_loss: 0.6973 - val_binary_accuracy: 0.5300
# Run:  1 / Accuracy on test ORIGINAL at epoch  2  is:  0.5299999713897705
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  2  is:  0.6050000190734863
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.4397 - binary_accuracy: 0.8233 - val_loss: 0.6644 - val_binary_accuracy: 0.6150
# Run:  1 / Accuracy on test ORIGINAL at epoch  3  is:  0.6150000095367432
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  3  is:  0.6650000214576721
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.2692 - binary_accuracy: 0.9033 - val_loss: 0.6762 - val_binary_accuracy: 0.6550
# Run:  1 / Accuracy on test ORIGINAL at epoch  4  is:  0.6549999713897705
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  4  is:  0.6650000214576721
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1695 - binary_accuracy: 0.9333 - val_loss: 0.6964 - val_binary_accuracy: 0.6700
# Run:  1 / Accuracy on test ORIGINAL at epoch  5  is:  0.6700000166893005
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  5  is:  0.6549999713897705
#
# 300/300 [==============================] - 11s 37ms/step - loss: 0.0992 - binary_accuracy: 0.9567 - val_loss: 0.7452 - val_binary_accuracy: 0.6400
# Run:  1 / Accuracy on test ORIGINAL at epoch  6  is:  0.6399999856948853
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  6  is:  0.6299999952316284
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0678 - binary_accuracy: 0.9767 - val_loss: 0.7963 - val_binary_accuracy: 0.6300
# Run:  1 / Accuracy on test ORIGINAL at epoch  7  is:  0.6299999952316284
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  7  is:  0.6449999809265137
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0564 - binary_accuracy: 0.9800 - val_loss: 0.9195 - val_binary_accuracy: 0.6350
# Run:  1 / Accuracy on test ORIGINAL at epoch  8  is:  0.6349999904632568
#
# Run:  1 / Accuracy on test AUGMENTED at epoch
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  18  is:  0.7149999737739563
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0575 - binary_accuracy: 0.9933 - val_loss: 1.4334 - val_binary_accuracy: 0.6050
# Run:  3 / Accuracy on test ORIGINAL at epoch  19  is:  0.6050000190734863
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  19  is:  0.5699999928474426
#
# Accuracies on ORIGINAL over epochs: [0.5049999952316284, 0.5, 0.5450000166893005, 0.5799999833106995, 0.625, 0.6200000047683716, 0.6349999904632568, 0.6000000238418579, 0.6150000095367432, 0.6100000143051147, 0.6399999856948853, 0.6200000047683716, 0.6200000047683716, 0.6499999761581421, 0.6200000047683716, 0.625, 0.6200000047683716, 0.6399999856948853, 0.6349999904632568, 0.6050000190734863]
#
# Accuracies on AUGMENTED over epochs: [0.5299999713897705, 0.5400000214576721, 0.6150000095367432, 0.6549999713897705, 0.675000011920929, 0.6449999809265137, 0.6499999761581421, 0.7250000238418579, 0.6399999856948853, 0.6499999761581421, 0.6399999856948853, 0.6850000023841858, 0.675000011920929, 0.6899999976158142, 0.6299999952316284, 0.6449999809265137, 0.6449999809265137, 0.6150000095367432, 0.7149999737739563, 0.5699999928474426]
#
#
# 300/300 [==============================] - 47s 153ms/step - loss: 0.7102 - binary_accuracy: 0.4767 - val_loss: 0.6930 - val_binary_accuracy: 0.5650
# Run:  4 / Accuracy on test ORIGINAL at epoch  0  is:  0.5649999976158142
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  0  is:  0.5699999928474426
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.6960 - binary_accuracy: 0.5300 - val_loss: 0.6941 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  1  is:  0.550000011920929
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.6258 - binary_accuracy: 0.7133 - val_loss: 0.6706 - val_binary_accuracy: 0.5350
# Run:  4 / Accuracy on test ORIGINAL at epoch  2  is:  0.5350000262260437
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  2  is:  0.6299999952316284
#
# 300/300 [==============================] - 12s 38ms/step - loss: 0.4763 - binary_accuracy: 0.8067 - val_loss: 0.6358 - val_binary_accuracy: 0.6300
# Run:  4 / Accuracy on test ORIGINAL at epoch  3  is:  0.6299999952316284
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  3  is:  0.6650000214576721
#
# 300/300 [==============================] - 12s 38ms/step - loss: 0.3404 - binary_accuracy: 0.8700 - val_loss: 0.6364 - val_binary_accuracy: 0.6400
# Run:  4 / Accuracy on test ORIGINAL at epoch  4  is:  0.6399999856948853
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  4  is:  0.6899999976158142
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1924 - binary_accuracy: 0.9267 - val_loss: 0.6690 - val_binary_accuracy: 0.6450
# Run:  4 / Accuracy on test ORIGINAL at epoch  5  is:  0.6449999809265137
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  5  is:  0.6850000023841858
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1173 - binary_accuracy: 0.9567 - val_loss: 0.7015 - val_binary_accuracy: 0.6500
# Run:  4 / Accuracy on test ORIGINAL at epoch  6  is:  0.6499999761581421
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  6  is:  0.7049999833106995
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0758 - binary_accuracy: 0.9667 - val_loss: 0.8605 - val_binary_accuracy: 0.6700
# Run:  4 / Accuracy on test ORIGINAL at epoch  7  is:  0.6700000166893005
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  7  is:  0.7300000190734863
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0807 - binary_accuracy: 0.9767 - val_loss: 0.8112 - val_binary_accuracy: 0.6350
# Run:  4 / Accuracy on test ORIGINAL at epoch  8  is:  0.6349999904632568
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  8  is:  0.6650000214576721
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0369 - binary_accuracy: 0.9900 - val_loss: 0.8816 - val_binary_accuracy: 0.6550
# Run:  4 / Accuracy on test ORIGINAL at epoch  9  is:  0.6549999713897705
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  9  is:  0.6800000071525574
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0253 - binary_accuracy: 0.9933 - val_loss: 0.9700 - val_binary_accuracy: 0.6600
# Run:  4 / Accuracy on test ORIGINAL at epoch  10  is:  0.6600000262260437
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  10  is:  0.699999988079071
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0463 - binary_accuracy: 0.9900 - val_loss: 1.0394 - val_binary_accuracy: 0.6700
# Run:  4 / Accuracy on test ORIGINAL at epoch  11  is:  0.6700000166893005
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  11  is:  0.6800000071525574
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0397 - binary_accuracy: 0.9900 - val_loss: 1.2409 - val_binary_accuracy: 0.6350
# Run:  4 / Accuracy on test ORIGINAL at epoch  12  is:  0.6349999904632568
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  12  is:  0.699999988079071
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.0403 - binary_accuracy: 0.9933 - val_loss: 1.3178 - val_binary_accuracy: 0.6350
# Run:  4 / Accuracy on test ORIGINAL at epoch  13  is:  0.6349999904632568
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  13  is:  0.7200000286102295
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0395 - binary_accuracy: 0.9933 - val_loss: 1.5588 - val_binary_accuracy: 0.6100
# Run:  4 / Accuracy on test ORIGINAL at epoch  14  is:  0.6100000143051147
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  14  is:  0.7350000143051147
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0332 - binary_accuracy: 0.9933 - val_loss: 1.6722 - val_binary_accuracy: 0.5950
# Run:  4 / Accuracy on test ORIGINAL at epoch  15  is:  0.5950000286102295
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  15  is:  0.7099999785423279
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0410 - binary_accuracy: 0.9933 - val_loss: 1.9004 - val_binary_accuracy: 0.5950
# Run:  4 / Accuracy on test ORIGINAL at epoch  16  is:  0.5950000286102295
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  16  is:  0.7049999833106995
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0300 - binary_accuracy: 0.9967 - val_loss: 2.2485 - val_binary_accuracy: 0.5600
# Run:  4 / Accuracy on test ORIGINAL at epoch  17  is:  0.5600000023841858
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  17  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 38ms/step - loss: 0.0311 - binary_accuracy: 0.9967 - val_loss: 2.3874 - val_binary_accuracy: 0.5600
# Run:  4 / Accuracy on test ORIGINAL at epoch  18  is:  0.5600000023841858
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  18  is:  0.6850000023841858
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0327 - binary_accuracy: 0.9933 - val_loss: 1.8642 - val_binary_accuracy: 0.5950
# Run:  4 / Accuracy on test ORIGINAL at epoch  19  is:  0.5950000286102295
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  19  is:  0.7099999785423279
#
# Accuracies on ORIGINAL over epochs: [0.5649999976158142, 0.5, 0.5350000262260437, 0.6299999952316284, 0.6399999856948853, 0.6449999809265137, 0.6499999761581421, 0.6700000166893005, 0.6349999904632568, 0.6549999713897705, 0.6600000262260437, 0.6700000166893005, 0.6349999904632568, 0.6349999904632568, 0.6100000143051147, 0.5950000286102295, 0.5950000286102295, 0.5600000023841858, 0.5600000023841858, 0.5950000286102295]
#
# Accuracies on AUGMENTED over epochs: [0.5699999928474426, 0.550000011920929, 0.6299999952316284, 0.6650000214576721, 0.6899999976158142, 0.6850000023841858, 0.7049999833106995, 0.7300000190734863, 0.6650000214576721, 0.6800000071525574, 0.699999988079071, 0.6800000071525574, 0.699999988079071, 0.7200000286102295, 0.7350000143051147, 0.7099999785423279, 0.7049999833106995, 0.7049999833106995, 0.6850000023841858, 0.7099999785423279]
#
#
# 300/300 [==============================] - 46s 150ms/step - loss: 0.7114 - binary_accuracy: 0.4900 - val_loss: 0.6929 - val_binary_accuracy: 0.5000
# Run:  5 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  0  is:  0.5
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.6947 - binary_accuracy: 0.5300 - val_loss: 0.6791 - val_binary_accuracy: 0.6700
# Run:  5 / Accuracy on test ORIGINAL at epoch  1  is:  0.6700000166893005
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  1  is:  0.5849999785423279
#
# 300/300 [==============================] - 11s 37ms/step - loss: 0.6278 - binary_accuracy: 0.7167 - val_loss: 0.6303 - val_binary_accuracy: 0.6550
# Run:  5 / Accuracy on test ORIGINAL at epoch  2  is:  0.6549999713897705
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  2  is:  0.6449999809265137
#
# 300/300 [==============================] - 11s 37ms/step - loss: 0.4615 - binary_accuracy: 0.8067 - val_loss: 0.6259 - val_binary_accuracy: 0.6450
# Run:  5 / Accuracy on test ORIGINAL at epoch  3  is:  0.6449999809265137
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  3  is:  0.6800000071525574
#
# 300/300 [==============================] - 11s 37ms/step - loss: 0.3266 - binary_accuracy: 0.8767 - val_loss: 0.6464 - val_binary_accuracy: 0.6500
# Run:  5 / Accuracy on test ORIGINAL at epoch  4  is:  0.6499999761581421
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  4  is:  0.6899999976158142
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.1914 - binary_accuracy: 0.9333 - val_loss: 0.6767 - val_binary_accuracy: 0.6500
# Run:  5 / Accuracy on test ORIGINAL at epoch  5  is:  0.6499999761581421
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  5  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 41ms/step - loss: 0.1208 - binary_accuracy: 0.9533 - val_loss: 0.7347 - val_binary_accuracy: 0.6850
# Run:  5 / Accuracy on test ORIGINAL at epoch  6  is:  0.6850000023841858
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  6  is:  0.6949999928474426
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0654 - binary_accuracy: 0.9700 - val_loss: 0.8236 - val_binary_accuracy: 0.6550
# Run:  5 / Accuracy on test ORIGINAL at epoch  7  is:  0.6549999713897705
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  7  is:  0.7250000238418579
#
# 300/300 [==============================] - 12s 38ms/step - loss: 0.0722 - binary_accuracy: 0.9800 - val_loss: 0.8375 - val_binary_accuracy: 0.6750
# Run:  5 / Accuracy on test ORIGINAL at epoch  8  is:  0.675000011920929
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  8  is:  0.6949999928474426
#
# 300/300 [==============================] - 12s 38ms/step - loss: 0.0226 - binary_accuracy: 0.9967 - val_loss: 0.9268 - val_binary_accuracy: 0.6550
# Run:  5 / Accuracy on test ORIGINAL at epoch  9  is:  0.6549999713897705
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  9  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0327 - binary_accuracy: 0.9933 - val_loss: 1.0200 - val_binary_accuracy: 0.6600
# Run:  5 / Accuracy on test ORIGINAL at epoch  10  is:  0.6600000262260437
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  10  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0238 - binary_accuracy: 0.9933 - val_loss: 1.2974 - val_binary_accuracy: 0.6200
# Run:  5 / Accuracy on test ORIGINAL at epoch  11  is:  0.6200000047683716
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  11  is:  0.7250000238418579
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0407 - binary_accuracy: 0.9900 - val_loss: 1.3665 - val_binary_accuracy: 0.6250
# Run:  5 / Accuracy on test ORIGINAL at epoch  12  is:  0.625
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  12  is:  0.7200000286102295
#
# 300/300 [==============================] - 11s 38ms/step - loss: 0.0538 - binary_accuracy: 0.9933 - val_loss: 1.4550 - val_binary_accuracy: 0.6050
# Run:  5 / Accuracy on test ORIGINAL at epoch  13  is:  0.6050000190734863
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  13  is:  0.7149999737739563
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0268 - binary_accuracy: 0.9967 - val_loss: 1.3718 - val_binary_accuracy: 0.6300
# Run:  5 / Accuracy on test ORIGINAL at epoch  14  is:  0.6299999952316284
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  14  is:  0.7049999833106995
#
# 300/300 [==============================] - 12s 38ms/step - loss: 0.0201 - binary_accuracy: 0.9967 - val_loss: 1.7796 - val_binary_accuracy: 0.5700
# Run:  5 / Accuracy on test ORIGINAL at epoch  15  is:  0.5699999928474426
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  15  is:  0.7099999785423279
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0235 - binary_accuracy: 0.9967 - val_loss: 2.0215 - val_binary_accuracy: 0.5650
# Run:  5 / Accuracy on test ORIGINAL at epoch  16  is:  0.5649999976158142
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  16  is:  0.7300000190734863
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0296 - binary_accuracy: 0.9967 - val_loss: 1.6012 - val_binary_accuracy: 0.5950
# Run:  5 / Accuracy on test ORIGINAL at epoch  17  is:  0.5950000286102295
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  17  is:  0.6800000071525574
#
# 300/300 [==============================] - 12s 39ms/step - loss: 0.0190 - binary_accuracy: 0.9933 - val_loss: 2.2689 - val_binary_accuracy: 0.5450
# Run:  5 / Accuracy on test ORIGINAL at epoch  18  is:  0.5450000166893005
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  18  is:  0.6949999928474426
#
# 300/300 [==============================] - 12s 38ms/step - loss: 0.0308 - binary_accuracy: 0.9933 - val_loss: 2.4315 - val_binary_accuracy: 0.5450
# Run:  5 / Accuracy on test ORIGINAL at epoch  19  is:  0.5450000166893005
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  19  is:  0.6850000023841858
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.6700000166893005, 0.6549999713897705, 0.6449999809265137, 0.6499999761581421, 0.6499999761581421, 0.6850000023841858, 0.6549999713897705, 0.675000011920929, 0.6549999713897705, 0.6600000262260437, 0.6200000047683716, 0.625, 0.6050000190734863, 0.6299999952316284, 0.5699999928474426, 0.5649999976158142, 0.5950000286102295, 0.5450000166893005, 0.5450000166893005]
#
# Accuracies on AUGMENTED over epochs: [0.5, 0.5849999785423279, 0.6449999809265137, 0.6800000071525574, 0.6899999976158142, 0.7049999833106995, 0.6949999928474426, 0.7250000238418579, 0.6949999928474426, 0.6800000071525574, 0.6800000071525574, 0.7250000238418579, 0.7200000286102295, 0.7149999737739563, 0.7049999833106995, 0.7099999785423279, 0.7300000190734863, 0.6800000071525574, 0.6949999928474426, 0.6850000023841858]
#
#
#
#
#  Over all runs maximum accuracies on ORIGINAL test set are: [0.6499999761581421, 0.6700000166893005, 0.6700000166893005, 0.675000011920929, 0.6850000023841858]
# The median for English is: 0.6700000166893005
#
#
#
#
#
#  Over all runs maximum accuracies on AUGMENTED test set are: [0.7049999833106995, 0.7250000238418579, 0.7250000238418579, 0.7300000190734863, 0.7350000143051147]
# The median for English is: 0.7250000238418579
#
#
#
# CNN Accuracy Score on Original Test set ->  0.6700000166893005 +/- 0.020000040531158447
# CNN Accuracy Score on AUGMENTED Test set ->  0.7250000238418579 +/- 0.020000040531158447
