# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/DA-ESWA/blob/main/code/evaluation/iss/CNN_ISS_augmented_IT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Investigating text data augmentation using back translation for author profiling
# - - -
# CNN ON HSS DS EXPERIMENTS NOTEBOOK
# - - -
# Convolutional Neural Network on Irony and Stereotype Spreaders Dataset augmented with IT backtranslation.
# Code by M. Siino.
#
# From the paper: "Investigating text data augmentation using back translation for author profiling" by M.Siino et al.

# %% [markdown]
# ## Importing modules.

# %%
import matplotlib.pyplot as plt
import os
import random
import re
import shutil
import string
import tensorflow as tf

import numpy as np

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from keras.models import Model
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

os.environ['TF_CUDNN_DETERMINISTIC']='true'
os.environ['TF_DETERMINISTIC_OPS']='true'

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
urlTrainingSet = "https://github.com/marco-siino/DA-ESWA/raw/main/data/iss/iss-training-augmented-it.zip"
training_set = tf.keras.utils.get_file("pan22-author-profiling-training-2022-03-29-augmented.zip", urlTrainingSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSet="https://github.com/marco-siino/DA-ESWA/raw/main/data/iss/iss-test-original.zip"
test_set = tf.keras.utils.get_file("pan22-author-profiling-test-2022-04-22-without_truth.zip", urlTestSet,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

urlTestSetAug="https://github.com/marco-siino/DA-ESWA/raw/main/data/iss/iss-test-augmented-it.zip"
test_set_aug = tf.keras.utils.get_file("pan22-author-profiling-test-2022-04-22-without_truth-augmented.zip", urlTestSetAug,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')
# Out:
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/iss/iss-training-augmented-it.zip
# 10118892/10118892 [==============================] - 0s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/iss/iss-test-original.zip
# 2446477/2446477 [==============================] - 1s 0us/step
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/iss/iss-test-augmented-it.zip
# 4226959/4226959 [==============================] - 0s 0us/step

# %%
training_set_dir = os.path.join(os.path.dirname(training_set), 'pan22-author-profiling-training-2022-03-29-augmented')
test_set_dir = os.path.join(os.path.dirname(test_set), 'pan22-author-profiling-test-2022-04-22-without_truth')
test_set_aug_dir = os.path.join(os.path.dirname(test_set_aug), 'pan22-author-profiling-test-2022-04-22-without_truth-augmented')

# !ls -A
# Out:
# .config
# pan22-author-profiling-test-2022-04-22-without_truth
# pan22-author-profiling-test-2022-04-22-without_truth-augmented
# pan22-author-profiling-test-2022-04-22-without_truth-augmented.zip
# pan22-author-profiling-test-2022-04-22-without_truth.zip
# pan22-author-profiling-training-2022-03-29-augmented
# pan22-author-profiling-training-2022-03-29-augmented.zip
# sample_data

# %% [markdown]
# ## Build folders hierarchy to use Keras folders preprocessing function.

# %%
### Training Folders. ###

# First level directory.
if not os.path.exists('train_dir_en'):
    os.makedirs('train_dir_en')

# Class labels directory.
if not os.path.exists('train_dir_en/0'):
    os.makedirs('train_dir_en/0')
if not os.path.exists('train_dir_en/1'):
    os.makedirs('train_dir_en/1')

# Make Py variables.
train_dir='train_dir_'

## Test Folders. ##
# First level directory.
if not os.path.exists('test_dir_en'):
    os.makedirs('test_dir_en')

# Class labels directory.
if not os.path.exists('test_dir_en/0'):
    os.makedirs('test_dir_en/0')
if not os.path.exists('test_dir_en/1'):
    os.makedirs('test_dir_en/1')

# Make Py variables.
test_dir='test_dir_'

## Test Augmented Folders. ##
# First level directory.
if not os.path.exists('test_aug_dir_en'):
    os.makedirs('test_aug_dir_en')

# Class labels directory.
if not os.path.exists('test_aug_dir_en/0'):
    os.makedirs('test_aug_dir_en/0')
if not os.path.exists('test_aug_dir_en/1'):
    os.makedirs('test_aug_dir_en/1')

# Make Py variables.
test_aug_dir='test_aug_dir_'

# !ls -A
# Out:
# .config
# pan22-author-profiling-test-2022-04-22-without_truth
# pan22-author-profiling-test-2022-04-22-without_truth-augmented
# pan22-author-profiling-test-2022-04-22-without_truth-augmented.zip
# pan22-author-profiling-test-2022-04-22-without_truth.zip
# pan22-author-profiling-training-2022-03-29-augmented
# pan22-author-profiling-training-2022-03-29-augmented.zip
# sample_data
# test_aug_dir_en
# test_dir_en
# train_dir_en

# %% [markdown]
# ## Set language and directory paths.

# %%
# Set en and es ground truth file path for train_dir. 
language='en'

truth_file_training_dir_en=training_set_dir+'/'+language+'/'
truth_file_training_path_en = truth_file_training_dir_en+'truth.txt'

truth_file_test_dir=test_set_dir
truth_file_test_path_en = truth_file_test_dir+'/'+'truth'+'.txt'

truth_file_test_aug_dir=test_set_aug_dir
truth_file_test_aug_path_en = truth_file_test_aug_dir+'/'+'truth'+'.txt'

# %% [markdown]
# ## Read truth.txt to organize training and test dataset folders.

# %%
# Open the file truth.txt with read only permit.
f = open(truth_file_training_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]
    if label == 'I':
      label = '1'
    elif label == 'N':
      label = '0'

    # Now move the file to the right folder.
    if os.path.exists(truth_file_training_dir_en+fNameXml):
      os.rename(truth_file_training_dir_en+fNameXml, './train_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]
    if label == 'I':
      label = '1'
    elif label == 'N':
      label = '0'

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_dir+'/'+language+'/'+fNameXml, './test_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# Open the file truth.txt with read only permit.
f = open(truth_file_test_aug_path_en, "r")
# use readline() to read the first line 
line = f.readline()
# use the read line to read further.
# If the file is not empty keep reading one line
# at a time, till the file is empty
while line:
    # Split line at :::
    x = line.split(":::")
    fNameXml = x[0]+'.xml'
    fNameTxt = x[0]+'.txt'
    # Second coord [0] gets just the first character (label) and not /n too.
    label = x[1][0]
    if label == 'I':
      label = '1'
    elif label == 'N':
      label = '0'

    # Now move the file to the right folder.
    if os.path.exists(truth_file_test_aug_dir+'/'+language+'/'+fNameXml):
      os.rename(truth_file_test_aug_dir+'/'+language+'/'+fNameXml, './test_aug_dir_'+language+'/'+label+'/'+fNameTxt )

    # use readline() to read next line
    line = f.readline()

# %% [markdown]
# ## Generate full dataset.

# %%
# Generate full randomized training set.
batch_size=1

en_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    train_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

en_test_aug_ds = tf.keras.preprocessing.text_dataset_from_directory(
    test_aug_dir+language, 
    batch_size=batch_size,
    shuffle=False
    )

train_ds=en_train_ds.shuffle(500,seed=1, reshuffle_each_iteration=False)
test_ds=en_test_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)
test_aug_ds=en_test_aug_ds.shuffle(200,seed=1, reshuffle_each_iteration=False)

train_ds_size=len(train_ds)
test_ds_size=len(test_ds)
test_aug_ds_size=len(test_aug_ds)
# Out:
# Found 420 files belonging to 2 classes.
# Found 180 files belonging to 2 classes.
# Found 180 files belonging to 2 classes.

# %% [markdown]
# ## Functions to pre-process source text.

# %%
# Preprocessing function to remove some noise due to the translation.
def clean_samples(input_data):
  tag_author_lang_en_removed = tf.strings.regex_replace(input_data,'', '')  
  tag_opening_documents = tf.strings.regex_replace(tag_author_lang_en_removed,'', '')
  tag_opening_cdata_removed = tf.strings.regex_replace(tag_opening_documents,'<\!\[CDATA\[', ' ')
  tag_closing_cdata_removed = tf.strings.regex_replace(tag_opening_cdata_removed,'\]\]>', ' >')
  tag_closing_documents = tf.strings.regex_replace(tag_closing_cdata_removed,'', '')
  output_data = tf.strings.regex_replace(tag_closing_documents,'', '')
  return output_data

# %% [markdown]
# ## Get the length of the longest sample in training set. Then adapt text.

# %%
def preprocess_and_adapt_ts(training_set):
  # Set a large sequence length to find the longest sample in the training set.
  sequence_length = 30000
  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  #vectorize_layer.get_vocabulary()

  model = tf.keras.models.Sequential()
  model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
  model.add(vectorize_layer)

  longest_sample_length=1

  for element in training_set:
    authorDocument=element[0]
    label=element[1]
    
    #print("Sample considered is: ", authorDocument[0].numpy())
    #print("Preprocessed: ", str(custom_standardization(authorDocument[0].numpy())))
    #print("And has label: ", label[0].numpy())

    out=model(authorDocument)
    # Convert token list to numpy array.
    token_list = out.numpy()[0]
    token_list = np.trim_zeros(token_list,'b')
    if longest_sample_length < len(token_list):
      longest_sample_length = len(token_list)

  print("Length of the longest sample is:", longest_sample_length)

  # After tokenization longest_sample_length covers all the document lenghts in our dataset.
  sequence_length = longest_sample_length

  vectorize_layer = TextVectorization(
      standardize=clean_samples,
      output_mode='int',
      output_sequence_length=sequence_length)

  # Finally adapt the vectorize layer.
  train_text = training_set.map(lambda x, y: x)
  vectorize_layer.adapt(train_text)
  return vectorize_layer

# %% [markdown]
# ## Some training hyperparameters...

# %%
# Word embedding dimensions.
embedding_dim = 100

num_runs = 5 
# No need to go over the 20th epoch...Overfitting begins.
num_epochs_per_run = 20

#opt = tf.keras.optimizers.RMSprop()

# %% [markdown]
# ## Vectorization

# %%
print("\n\n* * * * VECTORIZATION STARTED * * * *")

# Preprocess training set to build a dictionary.
vectorize_layer = preprocess_and_adapt_ts(train_ds)

max_features=len(vectorize_layer.get_vocabulary()) + 1
print("Vocabulary size is:", max_features)
# Out:
# * * * * VECTORIZATION STARTED * * * *
# Length of the longest sample is: 20382
# Vocabulary size is: 206590

# %% [markdown]
# ## Models definition, training and evaluation on original and on augmented test set.

# %%
tf.random.set_seed(1)

runs_accuracy = []
aug_runs_accuracy = []

for run in range(1,(num_runs+1)):
    epochs_accuracy = []
    aug_epochs_accuracy = []
    model = tf.keras.Sequential([
                                    tf.keras.Input(shape=(1,), dtype=tf.string),
                                    vectorize_layer,
                                    layers.Embedding(max_features + 1, embedding_dim),                     
                                    layers.Dropout(0.8),

                                    layers.Conv1D(256,16,activation='relu'),
                                    layers.MaxPooling1D(),
                                    layers.Dropout(0.6),

                                    layers.Dense(512,activation='relu'),
                           
                                    layers.GlobalAveragePooling1D(),
                                    layers.Dropout(0.2),
                                    layers.Dense(1)                            
    ])
    model.compile(loss=losses.BinaryCrossentropy(from_logits=True), optimizer='RMSprop', metrics=tf.metrics.BinaryAccuracy(threshold=0.0)) 

    for epoch in range (0,num_epochs_per_run):
        history = model.fit(
          train_ds,
          validation_data = test_ds,
          epochs=1,
          shuffle=False,
          # Comment the following line to do not save and download the model.
          #callbacks=[callbacks]
          )
        accuracy = history.history['val_binary_accuracy']
        aug_score = model.evaluate(test_aug_ds, verbose=0)
        aug_accuracy = aug_score[1]
        print("Run: ",run,"/ Accuracy on test ORIGINAL at epoch ",epoch," is: ", accuracy[0],"\n")
        print("Run: ",run,"/ Accuracy on test AUGMENTED at epoch ",epoch," is: ", aug_accuracy,"\n")
        epochs_accuracy.append(accuracy[0])
        aug_epochs_accuracy.append(aug_accuracy)

    print("Accuracies on ORIGINAL over epochs:",epochs_accuracy,"\n")
    runs_accuracy.append(max(epochs_accuracy))
    print("Accuracies on AUGMENTED over epochs:",aug_epochs_accuracy,"\n\n")
    aug_runs_accuracy.append(max(aug_epochs_accuracy))

runs_accuracy.sort()
aug_runs_accuracy.sort()
print("\n\n Over all runs maximum accuracies on ORIGINAL test set are:", runs_accuracy)
print("The median for English is:",runs_accuracy[2],"\n\n\n")
  
print("\n\n Over all runs maximum accuracies on AUGMENTED test set are:", aug_runs_accuracy)
print("The median for English is:",aug_runs_accuracy[2],"\n\n\n")

# Final Result on Original Test set
if (runs_accuracy[2]-runs_accuracy[0])>(runs_accuracy[4]-runs_accuracy[2]):
  max_range_from_median = runs_accuracy[2]-runs_accuracy[0]
else:
  max_range_from_median = runs_accuracy[4]-runs_accuracy[2]
final_result = str(runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on Original Test set -> ",final_result)

# Final result on AUGMENTED test set.
if (aug_runs_accuracy[2]-aug_runs_accuracy[0])>(aug_runs_accuracy[4]-aug_runs_accuracy[2]):
  max_range_from_median = aug_runs_accuracy[2]-aug_runs_accuracy[0]
else:
  max_range_from_median = aug_runs_accuracy[4]-aug_runs_accuracy[2]
final_result = str(aug_runs_accuracy[2])+" +/- "+ str(max_range_from_median)
print("CNN Accuracy Score on AUGMENTED Test set -> ",final_result)
# Out:
# 420/420 [==============================] - 166s 371ms/step - loss: 0.6784 - binary_accuracy: 0.5476 - val_loss: 0.7208 - val_binary_accuracy: 0.5056
# Run:  1 / Accuracy on test ORIGINAL at epoch  0  is:  0.5055555701255798
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  0  is:  0.8222222328186035
#
# 420/420 [==============================] - 91s 216ms/step - loss: 0.3945 - binary_accuracy: 0.8333 - val_loss: 0.6888 - val_binary_accuracy: 0.6722
# Run:  1 / Accuracy on test ORIGINAL at epoch  1  is:  0.6722221970558167
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  1  is:  0.9277777671813965
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.2602 - binary_accuracy: 0.9048 - val_loss: 0.5994 - val_binary_accuracy: 0.7444
# Run:  1 / Accuracy on test ORIGINAL at epoch  2  is:  0.7444444298744202
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  2  is:  0.9333333373069763
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.1908 - binary_accuracy: 0.9286 - val_loss: 0.4914 - val_binary_accuracy: 0.8167
# Run:  1 / Accuracy on test ORIGINAL at epoch  3  is:  0.8166666626930237
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  3  is:  0.9388889074325562
#
# 420/420 [==============================] - 88s 211ms/step - loss: 0.1328 - binary_accuracy: 0.9476 - val_loss: 0.4694 - val_binary_accuracy: 0.8333
# Run:  1 / Accuracy on test ORIGINAL at epoch  4  is:  0.8333333134651184
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  4  is:  0.9444444179534912
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.0898 - binary_accuracy: 0.9667 - val_loss: 0.4866 - val_binary_accuracy: 0.8444
# Run:  1 / Accuracy on test ORIGINAL at epoch  5  is:  0.8444444537162781
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  5  is:  0.9555555582046509
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.0541 - binary_accuracy: 0.9833 - val_loss: 0.5280 - val_binary_accuracy: 0.8500
# Run:  1 / Accuracy on test ORIGINAL at epoch  6  is:  0.8500000238418579
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  6  is:  0.9444444179534912
#
# 420/420 [==============================] - 99s 237ms/step - loss: 0.0297 - binary_accuracy: 0.9905 - val_loss: 0.7743 - val_binary_accuracy: 0.8000
# Run:  1 / Accuracy on test ORIGINAL at epoch  7  is:  0.800000011920929
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  7  is:  0.949999988079071
#
# 420/420 [==============================] - 88s 211ms/step - loss: 0.0304 - binary_accuracy: 0.9929 - val_loss: 0.6268 - val_binary_accuracy: 0.8556
# Run:  1 / Accuracy on test ORIGINAL at epoch  8  is:  0.855555534362793
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  8  is:  0.9444444179534912
#
# 420/420 [==============================] - 100s 238ms/step - loss: 0.0148 - binary_accuracy: 0.9976 - val_loss: 1.3426 - val_binary_accuracy: 0.7167
# Run:  1 / Accuracy on test ORIGINAL at epoch  9  is:  0.7166666388511658
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  9  is:  0.9388889074325562
#
# 420/420 [==============================] - 88s 211ms/step - loss: 0.0191 - binary_accuracy: 0.9929 - val_loss: 1.1788 - val_binary_accuracy: 0.7333
# Run:  1 / Accuracy on test ORIGINAL at epoch  10  is:  0.7333333492279053
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  10  is:  0.949999988079071
#
# 420/420 [==============================] - 91s 216ms/step - loss: 0.0063 - binary_accuracy: 0.9976 - val_loss: 1.4398 - val_binary_accuracy: 0.7222
# Run:  1 / Accuracy on test ORIGINAL at epoch  11  is:  0.7222222089767456
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  11  is:  0.9555555582046509
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.0064 - binary_accuracy: 0.9976 - val_loss: 1.1889 - val_binary_accuracy: 0.7444
# Run:  1 / Accuracy on test ORIGINAL at epoch  12  is:  0.7444444298744202
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  12  is:  0.9555555582046509
#
# 420/420 [==============================] - 91s 216ms/step - loss: 5.0333e-05 - binary_accuracy: 1.0000 - val_loss: 2.4924 - val_binary_accuracy: 0.6167
# Run:  1 / Accuracy on test ORIGINAL at epoch  13  is:  0.6166666746139526
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  13  is:  0.949999988079071
#
# 420/420 [==============================] - 88s 210ms/step - loss: 1.6835e-04 - binary_accuracy: 1.0000 - val_loss: 1.8068 - val_binary_accuracy: 0.6833
# Run:  1 / Accuracy on test ORIGINAL at epoch  14  is:  0.6833333373069763
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  14  is:  0.9555555582046509
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.0020 - binary_accuracy: 1.0000 - val_loss: 2.1726 - val_binary_accuracy: 0.6444
# Run:  1 / Accuracy on test ORIGINAL at epoch  15  is:  0.644444465637207
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  15  is:  0.9555555582046509
#
# 420/420 [==============================] - 90s 213ms/step - loss: 5.6946e-05 - binary_accuracy: 1.0000 - val_loss: 2.8004 - val_binary_accuracy: 0.6056
# Run:  1 / Accuracy on test ORIGINAL at epoch  16  is:  0.605555534362793
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  16  is:  0.9555555582046509
#
# 420/420 [==============================] - 89s 212ms/step - loss: 1.8974e-04 - binary_accuracy: 1.0000 - val_loss: 2.7397 - val_binary_accuracy: 0.6111
# Run:  1 / Accuracy on test ORIGINAL at epoch  17  is:  0.6111111044883728
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  17  is:  0.949999988079071
#
# 420/420 [==============================] - 88s 210ms/step - loss: 2.1772e-05 - binary_accuracy: 1.0000 - val_loss: 3.0686 - val_binary_accuracy: 0.5833
# Run:  1 / Accuracy on test ORIGINAL at epoch  18  is:  0.5833333134651184
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  18  is:  0.9444444179534912
#
# 420/420 [==============================] - 99s 236ms/step - loss: 3.5039e-05 - binary_accuracy: 1.0000 - val_loss: 3.1606 - val_binary_accuracy: 0.5889
# Run:  1 / Accuracy on test ORIGINAL at epoch  19  is:  0.5888888835906982
#
# Run:  1 / Accuracy on test AUGMENTED at epoch  19  is:  0.9388889074325562
#
# Accuracies on ORIGINAL over epochs: [0.5055555701255798, 0.6722221970558167, 0.7444444298744202, 0.8166666626930237, 0.8333333134651184, 0.8444444537162781, 0.8500000238418579, 0.800000011920929, 0.855555534362793, 0.7166666388511658, 0.7333333492279053, 0.7222222089767456, 0.7444444298744202, 0.6166666746139526, 0.6833333373069763, 0.644444465637207, 0.605555534362793, 0.6111111044883728, 0.5833333134651184, 0.5888888835906982]
#
# Accuracies on AUGMENTED over epochs: [0.8222222328186035, 0.9277777671813965, 0.9333333373069763, 0.9388889074325562, 0.9444444179534912, 0.9555555582046509, 0.9444444179534912, 0.949999988079071, 0.9444444179534912, 0.9388889074325562, 0.949999988079071, 0.9555555582046509, 0.9555555582046509, 0.949999988079071, 0.9555555582046509, 0.9555555582046509, 0.9555555582046509, 0.949999988079071, 0.9444444179534912, 0.9388889074325562]
#
#
# 420/420 [==============================] - 135s 317ms/step - loss: 0.6768 - binary_accuracy: 0.5571 - val_loss: 0.8152 - val_binary_accuracy: 0.5000
# Run:  2 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  0  is:  0.75
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.4000 - binary_accuracy: 0.8214 - val_loss: 1.1363 - val_binary_accuracy: 0.5111
# Run:  2 / Accuracy on test ORIGINAL at epoch  1  is:  0.5111111402511597
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  1  is:  0.9166666865348816
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.2547 - binary_accuracy: 0.9071 - val_loss: 0.8189 - val_binary_accuracy: 0.5944
# Run:  2 / Accuracy on test ORIGINAL at epoch  2  is:  0.5944444537162781
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  2  is:  0.9333333373069763
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.1873 - binary_accuracy: 0.9357 - val_loss: 0.9020 - val_binary_accuracy: 0.6111
# Run:  2 / Accuracy on test ORIGINAL at epoch  3  is:  0.6111111044883728
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  3  is:  0.9277777671813965
#
# 420/420 [==============================] - 88s 211ms/step - loss: 0.1286 - binary_accuracy: 0.9500 - val_loss: 0.6359 - val_binary_accuracy: 0.7611
# Run:  2 / Accuracy on test ORIGINAL at epoch  4  is:  0.7611111402511597
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  4  is:  0.9444444179534912
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.0857 - binary_accuracy: 0.9690 - val_loss: 0.7124 - val_binary_accuracy: 0.7389
# Run:  2 / Accuracy on test ORIGINAL at epoch  5  is:  0.7388888597488403
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  5  is:  0.9555555582046509
#
# 420/420 [==============================] - 89s 213ms/step - loss: 0.0400 - binary_accuracy: 0.9857 - val_loss: 0.8582 - val_binary_accuracy: 0.7333
# Run:  2 / Accuracy on test ORIGINAL at epoch  6  is:  0.7333333492279053
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  6  is:  0.949999988079071
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.0324 - binary_accuracy: 0.9905 - val_loss: 1.2834 - val_binary_accuracy: 0.6611
# Run:  2 / Accuracy on test ORIGINAL at epoch  7  is:  0.6611111164093018
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  7  is:  0.949999988079071
#
# 420/420 [==============================] - 89s 213ms/step - loss: 0.0362 - binary_accuracy: 0.9929 - val_loss: 1.2914 - val_binary_accuracy: 0.6778
# Run:  2 / Accuracy on test ORIGINAL at epoch  8  is:  0.6777777671813965
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  8  is:  0.9555555582046509
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.0199 - binary_accuracy: 0.9976 - val_loss: 1.1367 - val_binary_accuracy: 0.7000
# Run:  2 / Accuracy on test ORIGINAL at epoch  9  is:  0.699999988079071
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  9  is:  0.9555555582046509
#
# 420/420 [==============================] - 91s 217ms/step - loss: 0.0080 - binary_accuracy: 0.9976 - val_loss: 1.1470 - val_binary_accuracy: 0.7000
# Run:  2 / Accuracy on test ORIGINAL at epoch  10  is:  0.699999988079071
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  10  is:  0.9444444179534912
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.0081 - binary_accuracy: 0.9976 - val_loss: 2.7131 - val_binary_accuracy: 0.5889
# Run:  2 / Accuracy on test ORIGINAL at epoch  11  is:  0.5888888835906982
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  11  is:  0.9444444179534912
#
# 420/420 [==============================] - 89s 211ms/step - loss: 3.1170e-04 - binary_accuracy: 1.0000 - val_loss: 3.1061 - val_binary_accuracy: 0.5778
# Run:  2 / Accuracy on test ORIGINAL at epoch  12  is:  0.5777778029441833
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  12  is:  0.9444444179534912
#
# 420/420 [==============================] - 89s 213ms/step - loss: 1.4747e-04 - binary_accuracy: 1.0000 - val_loss: 3.4422 - val_binary_accuracy: 0.5778
# Run:  2 / Accuracy on test ORIGINAL at epoch  13  is:  0.5777778029441833
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  13  is:  0.9555555582046509
#
# 420/420 [==============================] - 88s 211ms/step - loss: 3.2338e-04 - binary_accuracy: 1.0000 - val_loss: 2.9122 - val_binary_accuracy: 0.6000
# Run:  2 / Accuracy on test ORIGINAL at epoch  14  is:  0.6000000238418579
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  14  is:  0.9611111283302307
#
# 420/420 [==============================] - 90s 215ms/step - loss: 5.3251e-04 - binary_accuracy: 1.0000 - val_loss: 4.1088 - val_binary_accuracy: 0.5500
# Run:  2 / Accuracy on test ORIGINAL at epoch  15  is:  0.550000011920929
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  15  is:  0.949999988079071
#
# 420/420 [==============================] - 89s 213ms/step - loss: 2.5819e-05 - binary_accuracy: 1.0000 - val_loss: 4.7909 - val_binary_accuracy: 0.5389
# Run:  2 / Accuracy on test ORIGINAL at epoch  16  is:  0.5388888716697693
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  16  is:  0.9333333373069763
#
# 420/420 [==============================] - 90s 213ms/step - loss: 1.4441e-04 - binary_accuracy: 1.0000 - val_loss: 5.0955 - val_binary_accuracy: 0.5389
# Run:  2 / Accuracy on test ORIGINAL at epoch  17  is:  0.5388888716697693
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  17  is:  0.9277777671813965
#
# 420/420 [==============================] - 89s 212ms/step - loss: 1.2462e-04 - binary_accuracy: 1.0000 - val_loss: 3.8731 - val_binary_accuracy: 0.5722
# Run:  2 / Accuracy on test ORIGINAL at epoch  18  is:  0.5722222328186035
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  18  is:  0.9611111283302307
#
# 420/420 [==============================] - 99s 237ms/step - loss: 3.0764e-05 - binary_accuracy: 1.0000 - val_loss: 4.9340 - val_binary_accuracy: 0.5389
# Run:  2 / Accuracy on test ORIGINAL at epoch  19  is:  0.5388888716697693
#
# Run:  2 / Accuracy on test AUGMENTED at epoch  19  is:  0.9388889074325562
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5111111402511597, 0.5944444537162781, 0.6111111044883728, 0.7611111402511597, 0.7388888597488403, 0.7333333492279053, 0.6611111164093018, 0.6777777671813965, 0.699999988079071, 0.699999988079071, 0.5888888835906982, 0.5777778029441833, 0.5777778029441833, 0.6000000238418579, 0.550000011920929, 0.5388888716697693, 0.5388888716697693, 0.5722222328186035, 0.5388888716697693]
#
# Accuracies on AUGMENTED over epochs: [0.75, 0.9166666865348816, 0.9333333373069763, 0.9277777671813965, 0.9444444179534912, 0.9555555582046509, 0.949999988079071, 0.949999988079071, 0.9555555582046509, 0.9555555582046509, 0.9444444179534912, 0.9444444179534912, 0.9444444179534912, 0.9555555582046509, 0.9611111283302307, 0.949999988079071, 0.9333333373069763, 0.9277777671813965, 0.9611111283302307, 0.9388889074325562]
#
#
# 420/420 [==============================] - 134s 316ms/step - loss: 0.6829 - binary_accuracy: 0.5357 - val_loss: 0.7950 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  0  is:  0.7333333492279053
#
# 420/420 [==============================] - 90s 214ms/step - loss: 0.4125 - binary_accuracy: 0.8310 - val_loss: 1.2520 - val_binary_accuracy: 0.5000
# Run:  3 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  1  is:  0.9277777671813965
#
# 420/420 [==============================] - 90s 213ms/step - loss: 0.2657 - binary_accuracy: 0.9024 - val_loss: 1.2682 - val_binary_accuracy: 0.5222
# Run:  3 / Accuracy on test ORIGINAL at epoch  2  is:  0.5222222208976746
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  2  is:  0.9333333373069763
#
# 420/420 [==============================] - 91s 216ms/step - loss: 0.1948 - binary_accuracy: 0.9286 - val_loss: 1.1502 - val_binary_accuracy: 0.5667
# Run:  3 / Accuracy on test ORIGINAL at epoch  3  is:  0.5666666626930237
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  3  is:  0.9333333373069763
#
# 420/420 [==============================] - 90s 214ms/step - loss: 0.1320 - binary_accuracy: 0.9548 - val_loss: 0.9948 - val_binary_accuracy: 0.6167
# Run:  3 / Accuracy on test ORIGINAL at epoch  4  is:  0.6166666746139526
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  4  is:  0.9444444179534912
#
# 420/420 [==============================] - 91s 216ms/step - loss: 0.0955 - binary_accuracy: 0.9667 - val_loss: 1.3240 - val_binary_accuracy: 0.6056
# Run:  3 / Accuracy on test ORIGINAL at epoch  5  is:  0.605555534362793
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  5  is:  0.9444444179534912
#
# 420/420 [==============================] - 90s 214ms/step - loss: 0.0456 - binary_accuracy: 0.9857 - val_loss: 0.9632 - val_binary_accuracy: 0.6778
# Run:  3 / Accuracy on test ORIGINAL at epoch  6  is:  0.6777777671813965
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  6  is:  0.9444444179534912
#
# 420/420 [==============================] - 99s 235ms/step - loss: 0.0339 - binary_accuracy: 0.9857 - val_loss: 1.5726 - val_binary_accuracy: 0.6278
# Run:  3 / Accuracy on test ORIGINAL at epoch  7  is:  0.6277777552604675
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  7  is:  0.949999988079071
#
# 420/420 [==============================] - 88s 211ms/step - loss: 0.0271 - binary_accuracy: 0.9952 - val_loss: 2.8021 - val_binary_accuracy: 0.5778
# Run:  3 / Accuracy on test ORIGINAL at epoch  8  is:  0.5777778029441833
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  8  is:  0.9333333373069763
#
# 420/420 [==============================] - 91s 216ms/step - loss: 0.0222 - binary_accuracy: 0.9976 - val_loss: 2.0145 - val_binary_accuracy: 0.6222
# Run:  3 / Accuracy on test ORIGINAL at epoch  9  is:  0.6222222447395325
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  9  is:  0.9555555582046509
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.0199 - binary_accuracy: 0.9976 - val_loss: 3.5590 - val_binary_accuracy: 0.5556
# Run:  3 / Accuracy on test ORIGINAL at epoch  10  is:  0.5555555820465088
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  10  is:  0.9222221970558167
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.0077 - binary_accuracy: 0.9976 - val_loss: 4.2091 - val_binary_accuracy: 0.5333
# Run:  3 / Accuracy on test ORIGINAL at epoch  11  is:  0.5333333611488342
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  11  is:  0.9222221970558167
#
# 420/420 [==============================] - 90s 213ms/step - loss: 6.9124e-04 - binary_accuracy: 1.0000 - val_loss: 3.9373 - val_binary_accuracy: 0.5389
# Run:  3 / Accuracy on test ORIGINAL at epoch  12  is:  0.5388888716697693
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  12  is:  0.9444444179534912
#
# 420/420 [==============================] - 89s 211ms/step - loss: 4.1454e-04 - binary_accuracy: 1.0000 - val_loss: 5.2382 - val_binary_accuracy: 0.5222
# Run:  3 / Accuracy on test ORIGINAL at epoch  13  is:  0.5222222208976746
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  13  is:  0.9277777671813965
#
# 420/420 [==============================] - 89s 212ms/step - loss: 4.1581e-05 - binary_accuracy: 1.0000 - val_loss: 5.3402 - val_binary_accuracy: 0.5222
# Run:  3 / Accuracy on test ORIGINAL at epoch  14  is:  0.5222222208976746
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  14  is:  0.9444444179534912
#
# 420/420 [==============================] - 90s 214ms/step - loss: 4.6494e-04 - binary_accuracy: 1.0000 - val_loss: 4.2538 - val_binary_accuracy: 0.5500
# Run:  3 / Accuracy on test ORIGINAL at epoch  15  is:  0.550000011920929
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  15  is:  0.9611111283302307
#
# 420/420 [==============================] - 90s 215ms/step - loss: 7.8124e-06 - binary_accuracy: 1.0000 - val_loss: 6.2189 - val_binary_accuracy: 0.5222
# Run:  3 / Accuracy on test ORIGINAL at epoch  16  is:  0.5222222208976746
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  16  is:  0.9277777671813965
#
# 420/420 [==============================] - 89s 212ms/step - loss: 4.6773e-05 - binary_accuracy: 1.0000 - val_loss: 6.2243 - val_binary_accuracy: 0.5222
# Run:  3 / Accuracy on test ORIGINAL at epoch  17  is:  0.5222222208976746
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  17  is:  0.9333333373069763
#
# 420/420 [==============================] - 90s 213ms/step - loss: 5.8263e-04 - binary_accuracy: 1.0000 - val_loss: 7.0004 - val_binary_accuracy: 0.5222
# Run:  3 / Accuracy on test ORIGINAL at epoch  18  is:  0.5222222208976746
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  18  is:  0.9111111164093018
#
# 420/420 [==============================] - 89s 212ms/step - loss: 1.1483e-05 - binary_accuracy: 1.0000 - val_loss: 6.1014 - val_binary_accuracy: 0.5278
# Run:  3 / Accuracy on test ORIGINAL at epoch  19  is:  0.5277777910232544
#
# Run:  3 / Accuracy on test AUGMENTED at epoch  19  is:  0.9388889074325562
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5222222208976746, 0.5666666626930237, 0.6166666746139526, 0.605555534362793, 0.6777777671813965, 0.6277777552604675, 0.5777778029441833, 0.6222222447395325, 0.5555555820465088, 0.5333333611488342, 0.5388888716697693, 0.5222222208976746, 0.5222222208976746, 0.550000011920929, 0.5222222208976746, 0.5222222208976746, 0.5222222208976746, 0.5277777910232544]
#
# Accuracies on AUGMENTED over epochs: [0.7333333492279053, 0.9277777671813965, 0.9333333373069763, 0.9333333373069763, 0.9444444179534912, 0.9444444179534912, 0.9444444179534912, 0.949999988079071, 0.9333333373069763, 0.9555555582046509, 0.9222221970558167, 0.9222221970558167, 0.9444444179534912, 0.9277777671813965, 0.9444444179534912, 0.9611111283302307, 0.9277777671813965, 0.9333333373069763, 0.9111111164093018, 0.9388889074325562]
#
#
# 420/420 [==============================] - 134s 314ms/step - loss: 0.6722 - binary_accuracy: 0.5548 - val_loss: 0.9138 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  0  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  0  is:  0.75
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.3850 - binary_accuracy: 0.8452 - val_loss: 1.6725 - val_binary_accuracy: 0.5000
# Run:  4 / Accuracy on test ORIGINAL at epoch  1  is:  0.5
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  1  is:  0.9166666865348816
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.2536 - binary_accuracy: 0.9095 - val_loss: 1.6241 - val_binary_accuracy: 0.5111
# Run:  4 / Accuracy on test ORIGINAL at epoch  2  is:  0.5111111402511597
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  2  is:  0.9333333373069763
#
# 420/420 [==============================] - 90s 213ms/step - loss: 0.1905 - binary_accuracy: 0.9286 - val_loss: 1.8530 - val_binary_accuracy: 0.5111
# Run:  4 / Accuracy on test ORIGINAL at epoch  3  is:  0.5111111402511597
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  3  is:  0.9166666865348816
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.1375 - binary_accuracy: 0.9500 - val_loss: 1.7005 - val_binary_accuracy: 0.5500
# Run:  4 / Accuracy on test ORIGINAL at epoch  4  is:  0.550000011920929
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  4  is:  0.9333333373069763
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.0838 - binary_accuracy: 0.9714 - val_loss: 2.0491 - val_binary_accuracy: 0.5500
# Run:  4 / Accuracy on test ORIGINAL at epoch  5  is:  0.550000011920929
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  5  is:  0.9222221970558167
#
# 420/420 [==============================] - 91s 216ms/step - loss: 0.0491 - binary_accuracy: 0.9833 - val_loss: 1.9807 - val_binary_accuracy: 0.5722
# Run:  4 / Accuracy on test ORIGINAL at epoch  6  is:  0.5722222328186035
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  6  is:  0.9555555582046509
#
# 420/420 [==============================] - 96s 229ms/step - loss: 0.0398 - binary_accuracy: 0.9905 - val_loss: 2.2830 - val_binary_accuracy: 0.5778
# Run:  4 / Accuracy on test ORIGINAL at epoch  7  is:  0.5777778029441833
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  7  is:  0.949999988079071
#
# 420/420 [==============================] - 95s 225ms/step - loss: 0.0215 - binary_accuracy: 0.9929 - val_loss: 3.6736 - val_binary_accuracy: 0.5222
# Run:  4 / Accuracy on test ORIGINAL at epoch  8  is:  0.5222222208976746
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  8  is:  0.9333333373069763
#
# 420/420 [==============================] - 92s 218ms/step - loss: 0.0190 - binary_accuracy: 0.9976 - val_loss: 3.4729 - val_binary_accuracy: 0.5556
# Run:  4 / Accuracy on test ORIGINAL at epoch  9  is:  0.5555555820465088
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  9  is:  0.949999988079071
#
# 420/420 [==============================] - 92s 218ms/step - loss: 0.0167 - binary_accuracy: 0.9976 - val_loss: 4.7650 - val_binary_accuracy: 0.5222
# Run:  4 / Accuracy on test ORIGINAL at epoch  10  is:  0.5222222208976746
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  10  is:  0.9444444179534912
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.0026 - binary_accuracy: 1.0000 - val_loss: 6.4564 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  11  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  11  is:  0.9111111164093018
#
# 420/420 [==============================] - 88s 210ms/step - loss: 9.5335e-04 - binary_accuracy: 1.0000 - val_loss: 6.3848 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  12  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  12  is:  0.9388889074325562
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.0011 - binary_accuracy: 1.0000 - val_loss: 6.2356 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  13  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  13  is:  0.9444444179534912
#
# 420/420 [==============================] - 88s 211ms/step - loss: 1.6577e-04 - binary_accuracy: 1.0000 - val_loss: 6.7273 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  14  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  14  is:  0.9277777671813965
#
# 420/420 [==============================] - 88s 209ms/step - loss: 3.1348e-04 - binary_accuracy: 1.0000 - val_loss: 7.1404 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  15  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  15  is:  0.9111111164093018
#
# 420/420 [==============================] - 88s 209ms/step - loss: 2.7580e-04 - binary_accuracy: 1.0000 - val_loss: 6.7944 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  16  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  16  is:  0.9444444179534912
#
# 420/420 [==============================] - 97s 232ms/step - loss: 3.5420e-05 - binary_accuracy: 1.0000 - val_loss: 8.2211 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  17  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  17  is:  0.9166666865348816
#
# 420/420 [==============================] - 87s 208ms/step - loss: 8.0846e-05 - binary_accuracy: 1.0000 - val_loss: 8.4608 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  18  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  18  is:  0.9166666865348816
#
# 420/420 [==============================] - 87s 208ms/step - loss: 4.9500e-05 - binary_accuracy: 1.0000 - val_loss: 8.2610 - val_binary_accuracy: 0.5167
# Run:  4 / Accuracy on test ORIGINAL at epoch  19  is:  0.5166666507720947
#
# Run:  4 / Accuracy on test AUGMENTED at epoch  19  is:  0.8999999761581421
#
# Accuracies on ORIGINAL over epochs: [0.5, 0.5, 0.5111111402511597, 0.5111111402511597, 0.550000011920929, 0.550000011920929, 0.5722222328186035, 0.5777778029441833, 0.5222222208976746, 0.5555555820465088, 0.5222222208976746, 0.5166666507720947, 0.5166666507720947, 0.5166666507720947, 0.5166666507720947, 0.5166666507720947, 0.5166666507720947, 0.5166666507720947, 0.5166666507720947, 0.5166666507720947]
#
# Accuracies on AUGMENTED over epochs: [0.75, 0.9166666865348816, 0.9333333373069763, 0.9166666865348816, 0.9333333373069763, 0.9222221970558167, 0.9555555582046509, 0.949999988079071, 0.9333333373069763, 0.949999988079071, 0.9444444179534912, 0.9111111164093018, 0.9388889074325562, 0.9444444179534912, 0.9277777671813965, 0.9111111164093018, 0.9444444179534912, 0.9166666865348816, 0.9166666865348816, 0.8999999761581421]
#
#
# 420/420 [==============================] - 132s 311ms/step - loss: 0.6862 - binary_accuracy: 0.5381 - val_loss: 0.6973 - val_binary_accuracy: 0.5056
# Run:  5 / Accuracy on test ORIGINAL at epoch  0  is:  0.5055555701255798
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  0  is:  0.7611111402511597
#
# 420/420 [==============================] - 88s 209ms/step - loss: 0.4187 - binary_accuracy: 0.8071 - val_loss: 0.8719 - val_binary_accuracy: 0.5333
# Run:  5 / Accuracy on test ORIGINAL at epoch  1  is:  0.5333333611488342
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  1  is:  0.9277777671813965
#
# 420/420 [==============================] - 87s 208ms/step - loss: 0.2582 - binary_accuracy: 0.9048 - val_loss: 0.6613 - val_binary_accuracy: 0.7056
# Run:  5 / Accuracy on test ORIGINAL at epoch  2  is:  0.7055555582046509
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  2  is:  0.9388889074325562
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.1796 - binary_accuracy: 0.9429 - val_loss: 0.7001 - val_binary_accuracy: 0.7056
# Run:  5 / Accuracy on test ORIGINAL at epoch  3  is:  0.7055555582046509
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  3  is:  0.9333333373069763
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.1312 - binary_accuracy: 0.9476 - val_loss: 0.5562 - val_binary_accuracy: 0.8000
# Run:  5 / Accuracy on test ORIGINAL at epoch  4  is:  0.800000011920929
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  4  is:  0.9444444179534912
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.0856 - binary_accuracy: 0.9667 - val_loss: 0.7175 - val_binary_accuracy: 0.7667
# Run:  5 / Accuracy on test ORIGINAL at epoch  5  is:  0.7666666507720947
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  5  is:  0.9444444179534912
#
# 420/420 [==============================] - 88s 210ms/step - loss: 0.0476 - binary_accuracy: 0.9833 - val_loss: 0.6417 - val_binary_accuracy: 0.8167
# Run:  5 / Accuracy on test ORIGINAL at epoch  6  is:  0.8166666626930237
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  6  is:  0.949999988079071
#
# 420/420 [==============================] - 89s 212ms/step - loss: 0.0278 - binary_accuracy: 0.9905 - val_loss: 0.7456 - val_binary_accuracy: 0.7889
# Run:  5 / Accuracy on test ORIGINAL at epoch  7  is:  0.7888888716697693
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  7  is:  0.949999988079071
#
# 420/420 [==============================] - 89s 211ms/step - loss: 0.0259 - binary_accuracy: 0.9905 - val_loss: 0.7994 - val_binary_accuracy: 0.7500
# Run:  5 / Accuracy on test ORIGINAL at epoch  8  is:  0.75
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  8  is:  0.9555555582046509
#
# 420/420 [==============================] - 88s 209ms/step - loss: 0.0170 - binary_accuracy: 0.9976 - val_loss: 1.5890 - val_binary_accuracy: 0.6722
# Run:  5 / Accuracy on test ORIGINAL at epoch  9  is:  0.6722221970558167
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  9  is:  0.9444444179534912
#
# 420/420 [==============================] - 88s 209ms/step - loss: 0.0108 - binary_accuracy: 0.9976 - val_loss: 2.1080 - val_binary_accuracy: 0.6278
# Run:  5 / Accuracy on test ORIGINAL at epoch  10  is:  0.6277777552604675
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  10  is:  0.9444444179534912
#
# 420/420 [==============================] - 87s 208ms/step - loss: 0.0056 - binary_accuracy: 0.9976 - val_loss: 2.4113 - val_binary_accuracy: 0.6167
# Run:  5 / Accuracy on test ORIGINAL at epoch  11  is:  0.6166666746139526
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  11  is:  0.949999988079071
#
# 420/420 [==============================] - 98s 234ms/step - loss: 0.0017 - binary_accuracy: 1.0000 - val_loss: 2.5910 - val_binary_accuracy: 0.6111
# Run:  5 / Accuracy on test ORIGINAL at epoch  12  is:  0.6111111044883728
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  12  is:  0.9555555582046509
#
# 420/420 [==============================] - 88s 209ms/step - loss: 6.8089e-05 - binary_accuracy: 1.0000 - val_loss: 3.6008 - val_binary_accuracy: 0.5611
# Run:  5 / Accuracy on test ORIGINAL at epoch  13  is:  0.5611110925674438
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  13  is:  0.9444444179534912
#
# 420/420 [==============================] - 88s 210ms/step - loss: 4.6317e-05 - binary_accuracy: 1.0000 - val_loss: 2.5892 - val_binary_accuracy: 0.6111
# Run:  5 / Accuracy on test ORIGINAL at epoch  14  is:  0.6111111044883728
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  14  is:  0.9611111283302307
#
# 420/420 [==============================] - 88s 210ms/step - loss: 4.6692e-05 - binary_accuracy: 1.0000 - val_loss: 3.9029 - val_binary_accuracy: 0.5556
# Run:  5 / Accuracy on test ORIGINAL at epoch  15  is:  0.5555555820465088
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  15  is:  0.9444444179534912
#
# 420/420 [==============================] - 88s 209ms/step - loss: 1.2323e-05 - binary_accuracy: 1.0000 - val_loss: 4.0796 - val_binary_accuracy: 0.5556
# Run:  5 / Accuracy on test ORIGINAL at epoch  16  is:  0.5555555820465088
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  16  is:  0.9444444179534912
#
# 420/420 [==============================] - 103s 245ms/step - loss: 1.3537e-04 - binary_accuracy: 1.0000 - val_loss: 2.7119 - val_binary_accuracy: 0.6167
# Run:  5 / Accuracy on test ORIGINAL at epoch  17  is:  0.6166666746139526
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  17  is:  0.9611111283302307
#
# 420/420 [==============================] - 89s 213ms/step - loss: 6.1867e-05 - binary_accuracy: 1.0000 - val_loss: 3.2311 - val_binary_accuracy: 0.5944
# Run:  5 / Accuracy on test ORIGINAL at epoch  18  is:  0.5944444537162781
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  18  is:  0.949999988079071
#
# 420/420 [==============================] - 88s 209ms/step - loss: 3.8564e-05 - binary_accuracy: 1.0000 - val_loss: 3.4107 - val_binary_accuracy: 0.5944
# Run:  5 / Accuracy on test ORIGINAL at epoch  19  is:  0.5944444537162781
#
# Run:  5 / Accuracy on test AUGMENTED at epoch  19  is:  0.949999988079071
#
# Accuracies on ORIGINAL over epochs: [0.5055555701255798, 0.5333333611488342, 0.7055555582046509, 0.7055555582046509, 0.800000011920929, 0.7666666507720947, 0.8166666626930237, 0.7888888716697693, 0.75, 0.6722221970558167, 0.6277777552604675, 0.6166666746139526, 0.6111111044883728, 0.5611110925674438, 0.6111111044883728, 0.5555555820465088, 0.5555555820465088, 0.6166666746139526, 0.5944444537162781, 0.5944444537162781]
#
# Accuracies on AUGMENTED over epochs: [0.7611111402511597, 0.9277777671813965, 0.9388889074325562, 0.9333333373069763, 0.9444444179534912, 0.9444444179534912, 0.949999988079071, 0.949999988079071, 0.9555555582046509, 0.9444444179534912, 0.9444444179534912, 0.949999988079071, 0.9555555582046509, 0.9444444179534912, 0.9611111283302307, 0.9444444179534912, 0.9444444179534912, 0.9611111283302307, 0.949999988079071, 0.949999988079071]
#
#
#
#
#  Over all runs maximum accuracies on ORIGINAL test set are: [0.5777778029441833, 0.6777777671813965, 0.7611111402511597, 0.8166666626930237, 0.855555534362793]
# The median for English is: 0.7611111402511597
#
#
#
#
#
#  Over all runs maximum accuracies on AUGMENTED test set are: [0.9555555582046509, 0.9555555582046509, 0.9611111283302307, 0.9611111283302307, 0.9611111283302307]
# The median for English is: 0.9611111283302307
#
#
#
# CNN Accuracy Score on Original Test set ->  0.7611111402511597 +/- 0.18333333730697632
# CNN Accuracy Score on AUGMENTED Test set ->  0.9611111283302307 +/- 0.005555570125579834
