# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/DA-ESWA/blob/main/code/augmentation/FNS_TestSet_Augmentation_IT_NB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing modules.

# %%
import os
import os.path
from os import path
import re
import shutil
import string
import tensorflow as tf

# !pip install -U deep-translator
from deep_translator import GoogleTranslator
from io import open
from pathlib import Path
from google.colab import files
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deep-translator
#   Downloading deep_translator-1.10.1-py3-none-any.whl (35 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from deep-translator) (2.25.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2022.12.7)
# Installing collected packages: soupsieve, beautifulsoup4, deep-translator
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.2 deep-translator-1.10.1 soupsieve-2.4

# %%
# !pip install xmltodict
import xmltodict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %% [markdown]
# ## Importing DS and extract in current working directory.

# %%
# Url obtained starting from this: https://drive.google.com/file/d/19ZcqEv88euKB71HfAWjTGN3uCKp2qsfP/ and forcing export=download.
train_set_url = 'https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-original.zip'  # train FNS
train_set_path = tf.keras.utils.get_file("pan20-author-profiling-test-2020-02-23.zip", train_set_url,
                                    extract=True, archive_format='zip',cache_dir='.',
                                    cache_subdir='')

train_set_dir = os.path.join(os.path.dirname(train_set_path), 'pan20-author-profiling-test-2020-02-23.zip')

print(train_set_path)
print(train_set_dir)
# Out:
# Downloading data from https://github.com/marco-siino/DA-ESWA/raw/main/data/fns/fns-test-original.zip
# 864693/864693 [==============================] - 0s 0us/step
# ./pan20-author-profiling-test-2020-02-23.zip
# ./pan20-author-profiling-test-2020-02-23.zip

# %% [markdown]
# ## Function to pre-process source text.

# %%
def custom_standardization(text):
  tag_open_CDATA_removed = re.sub('<\!\[CDATA\[', ' ',text)
  tag_closed_CDATA_removed = re.sub('\]{1,}>', ' ',tag_open_CDATA_removed)
  tag_author_lang_en_removed = re.sub('<author lang="en">', ' ',tag_closed_CDATA_removed)
  tag_author_lang_en_removed = re.sub('<author lang="en"', ' ',tag_closed_CDATA_removed)
  #only for test remove if needed
  tag_author_lang_en_removed = re.sub('class="0">', ' ', tag_author_lang_en_removed )
  tag_author_lang_en_removed = re.sub('class="1">', ' ', tag_author_lang_en_removed )
  ######
  tag_closed_author_removed = re.sub('</author>', '', tag_author_lang_en_removed)
  tag_closed_author_removed = re.sub('</author', '', tag_closed_author_removed)
  tag_open_documents_removed = re.sub('<documents>\n(\t){0,2}', '',tag_closed_author_removed)
  tag_closed_documents_removed = re.sub('</documents>\n(\t){0,2}', ' ',tag_open_documents_removed)
  lowercased_text = tag_closed_documents_removed.lower()
  return lowercased_text

# %% [markdown]
# ## Data Augmentation function.

# %%
def chunkstring(string, length):
  res = list((string[0+i:length+i] for i in range(0, len(string), length)))
  return res

def enhance_one_sample(sample, TARGET='it', return_both=True):  
  preprocessed_text = custom_standardization(sample)

  #chunk to avoid character limits  
  TOBETRANS = chunkstring(preprocessed_text, 4000)
  translated_it = GoogleTranslator(source='en', target=TARGET).translate_batch(TOBETRANS)
  reversed_trans = GoogleTranslator(source=TARGET, target='en').translate_batch(translated_it)
  merged_chunks =''.join(reversed_trans)
  enhanced_sample = preprocessed_text+merged_chunks
  if return_both == False:
    enhanced_sample = merged_chunks
  return enhanced_sample

# %% [markdown]
# # Generating augmented train set.

# %%
## Generate the augmented training set as a zip file.

# pan22-author-profiling-training-2022-03-29-augmented.zip has to be created.
if not os.path.exists('pan20-author-profiling-test-2020-02-23-augmented'):
    os.makedirs('pan20-author-profiling-test-2020-02-23-augmented')
if not os.path.exists('pan20-author-profiling-test-2020-02-23-augmented/en/'):
    os.makedirs('pan20-author-profiling-test-2020-02-23-augmented/en/')

# %%
# Copy the ground truth file.
if os.path.exists('/content/pan20-author-profiling-test-2020-02-23'):
        shutil.copyfile('/content/pan20-author-profiling-test-2020-02-23/truth.txt', '/content/pan20-author-profiling-test-2020-02-23-augmented/truth.txt')

# %%
file_nr = 0
count_errors = 0
for filename in os.listdir('pan20-author-profiling-test-2020-02-23/en/'):
  file_nr += 1
  x = filename.split(".")      
  author_id = x[0]
  print("File nr.:", file_nr)
  print("Filename:", filename)
  text = open('pan20-author-profiling-test-2020-02-23/en/'+filename, 'r').read()
  try:
    enhanced_sample = enhance_one_sample(text, TARGET='it')
    #de_back = enhance_one_sample(text, TARGET='de', return_both=False)
    #enhanced_sample = enhanced_sample + de_back    
    f = open("pan20-author-profiling-test-2020-02-23-augmented/en/"+author_id+".xml", "a")
    f.write(enhanced_sample)
    f.close()
    print('Succes')
  except:
    print('!!! FAILED !!!!')
    count_errors += 1
    f = open("pan20-author-profiling-test-2020-02-23-augmented/en/"+author_id+".xml", "a")
    preprocessed_text = custom_standardization(text)
    f.write(preprocessed_text)
    f.close()

print('cunt err', count_errors)
# !zip -r pan20-author-profiling-test-2020-02-23-augmented.zip pan20-author-profiling-test-2020-02-23-augmented
# If automatic download doesn't start, open the directory browser on the left menu and download the zip file manually.
files.download("pan20-author-profiling-test-2020-02-23-augmented.zip")
# Out:
# File nr.: 1
# Filename: 66xfnef04078fl2cjtpl75lcoa3urlw5.xml
# Succes
# File nr.: 2
# Filename: x8hzj2iwaod69ghfm2trykq4nda7wsya.xml
# Succes
# File nr.: 3
# Filename: g8f4l0wj2xptb483ivgytzcslwnj24e4.xml
# Succes
# File nr.: 4
# Filename: 6cbcvkpdf0hhh7or4xo9in3iwex4lq0s.xml
# Succes
# File nr.: 5
# Filename: ldrqcujt9ytmblge312p0wi64abt0vdj.xml
# Succes
# File nr.: 6
# Filename: pzzy8v2i20vq0cpijs6l3081938r7eev.xml
# Succes
# File nr.: 7
# Filename: pg8ox5qkjf6dwapf1nhei3tf1ohn6fln.xml
# Succes
# File nr.: 8
# Filename: 8p6ioi78mxizzakpagdmvmlphhwd0dgs.xml
# Succes
# File nr.: 9
# Filename: l2hpq42zdxr794yeebxxd33lo4ytfupc.xml
# Succes
# File nr.: 10
# Filename: riecahk95ttxibfy7oh1v0bxkiighjei.xml
# Succes
# File nr.: 11
# Filename: f4bepnrk5576eun0bpmpvx0frd05ih54.xml
# Succes
# File nr.: 12
# Filename: kgbdfnx8y7a9zxtvopmqesmcu91u0t48.xml
# Succes
# File nr.: 13
# Filename: 8h0mkknjo83qd8bdazzb0bmo619c4juk.xml
# Succes
# File nr.: 14
# Filename: 9uoaby907nei5mdzukbhspwi1q9l9k1h.xml
# Succes
# File nr.: 15
# Filename: q7fvurr0w3b8q8pykkk0mq1phokumf01.xml
# Succes
# File nr.: 16
# Filename: utay0xqk1j1cfw4lh41wuoy1wcp981lw.xml
# Succes
# File nr.: 17
# Filename: es6ffjcgg0szpb70t6xc1rglhr3s8arr.xml
# Succes
# File nr.: 18
# Filename: egbk32wz84ehkr2baphyuv1dehmld2xz.xml
# Succes
# File nr.: 19
# Filename: k749d234s1wa966ec9ec2qj07b1r05wu.xml
# Succes
# File nr.: 20
# Filename: 4fz9avg9jjyo33i2hwpj09v40efjed7s.xml
# Succes
# File nr.: 21
# Filename: 034rhbdu5dxg1p7ugwbdvo9oze9680kn.xml
# Succes
# File nr.: 22
# Filename: 7pjpn6mfoud05dpk9hseotov71gdvo5o.xml
# Succes
# File nr.: 23
# Filename: qk0cx2udz4l5hsdsb2c6sen3ie8pm14n.xml
# Succes
# File nr.: 24
# Filename: 8p73jt3eamtcbohxn5u6768a8ldr1b23.xml
# Succes
# File nr.: 25
# Filename: w1wllh2j0qvub6z53erdmfbeib5ouwd6.xml
# Succes
# File nr.: 26
# Filename: e28yucizt3v1cmvpk81gpi5y4ngs4435.xml
# Succes
# File nr.: 27
# Filename: 7ecqujmn3aaydq2h2r5tif3pz01foacv.xml
# Succes
# File nr.: 28
# Filename: mxlk82be05zjlh9r48oeso5pmpvg3a6u.xml
# Succes
# File nr.: 29
# Filename: tf3to8esasm8as73n6owuzd5qv3utaef.xml
# Succes
# File nr.: 30
# Filename: 7xwmf2vk8jk9n9jaday4az4rkyw1b4vm.xml
# Succes
# File nr.: 31
# Filename: l5vg2j2ckof28jv68x4n1c9w6yrxatn5.xml
# Succes
# File nr.: 32
# Filename: q85iktn8w6ogmhre7f5cmk2nj5qtlfqq.xml
# Succes
# File nr.: 33
# Filename: fbpbk27s1rsb20wh7xw8kdvt11mp5le0.xml
# Succes
# File nr.: 34
# Filename: dyl4i7km4z7vmk96s006a2z60q2infxk.xml
# Succes
# File nr.: 35
# Filename: eck9ts2xfxnwksh2wbx4c3flarwthvxl.xml
# Succes
# File nr.: 36
# Filename: yjba0by6o2uszjzht1ldd3dm62tgbr9t.xml
# Succes
# File nr.: 37
# Filename: 6uuilhed54v6yswokyzfll5gycw80eks.xml
# Succes
# File nr.: 38
# Filename: vz3569oum44rvbfbk5kv7adaa3ohox6d.xml
# Succes
# File nr.: 39
# Filename: elo6g3lmqrvzs2o98y9ie5j2qxsiyt7c.xml
# Succes
# File nr.: 40
# Filename: pkcs8qkbbv7v0dhq6mopz5zvt3s0e994.xml
# Succes
# File nr.: 41
# Filename: 7zoehegooirc260cp6gfxsb4bymmb10w.xml
# Succes
# File nr.: 42
# Filename: wfna6ij2k26yjrn33lpnnla4xdrmhdz5.xml
# Succes
# File nr.: 43
# Filename: jbg783o8rywwx04jgj2sspp8o0ajc10b.xml
# Succes
# File nr.: 44
# Filename: 386tsg5k7ixadn6mwx0lnaei2qnz2z08.xml
# Succes
# File nr.: 45
# Filename: py7qkdr7y4nkacpgc0oripgspg50uzdm.xml
# Succes
# File nr.: 46
# Filename: 1gzwx8vr76dnq3xbl9fdivpy85babsw0.xml
# Succes
# File nr.: 47
# Filename: g5bzewk9ygkkuflcjb6xcgplbhn28q5v.xml
# Succes
# File nr.: 48
# Filename: pcjpcc08d22t8xusx72df8sv6bk20j2t.xml
# Succes
# File nr.: 49
# Filename: z1aeg736jfekwcf4uxt3plpi4v8937x5.xml
# Succes
# File nr.: 50
# Filename: dpmn5a3mwg8a5ejkw2bco6o2pg8exj3t.xml
# Succes
# File nr.: 51
# Filename: hnbhfmj6p15xswpshumjpkpmlx0dqs41.xml
# Succes
# File nr.: 52
# Filename: n2b1u1n0f9j7dyy2vkkeys5an0tel24u.xml
# Succes
# File nr.: 53
# Filename: zapxq6vcsq2m01gjwzhidnk633f4xn1n.xml
# Succes
# File nr.: 54
# Filename: gs22gehym1pwqjx6x72oat5dex6o2ukh.xml
# Succes
# File nr.: 55
# Filename: cd7e3cc3mv5ohq3tsuu1qv97c0iz8mdh.xml
# Succes
# File nr.: 56
# Filename: i107gznzaqolzh3u8rckn4vabtsixso9.xml
# Succes
# File nr.: 57
# Filename: u166lshn3v3y1xjcbtm8kq4hpy7vom6e.xml
# Succes
# File nr.: 58
# Filename: wn9joxy5oz0o6vcxtyjlqpe53p9seb88.xml
# Succes
# File nr.: 59
# Filename: z5ccwleppr2zwec3wegltgj1nferirbp.xml
# Succes
# File nr.: 60
# Filename: 0t48ql5anfinhcjrxqmiykt4ffe8xdz2.xml
# Succes
# File nr.: 61
# Filename: 0wjyoghoccmi7fkvoo9u8ghanwvalb6f.xml
# Succes
# File nr.: 62
# Filename: vgxcjzvkacdojykpw9f9widil1bs04ty.xml
# Succes
# File nr.: 63
# Filename: xysuqwlavhym71rvs2tzogxbzk7e13sa.xml
# Succes
# File nr.: 64
# Filename: yge4pe12pxx4sw6yk0jgyq9c3xke9ge7.xml
# Succes
# File nr.: 65
# Filename: 0pthhz6l89xsaxqkgneo9mlkixswsqc0.xml
# Succes
# File nr.: 66
# Filename: kk3y5alqkzhu15dg72okxwl4jbrgmpbl.xml
# Succes
# File nr.: 67
# Filename: hgacdhnyenzuq8kbfg0tkfjq5nt0v0uc.xml
# Succes
# File nr.: 68
# Filename: xpgvcgm46lmpfl2f7lf64zv45zhzvehr.xml
# Succes
# File nr.: 69
# Filename: tjersiuobx2lh5yipdbokuzxz0pu0iin.xml
# Succes
# File nr.: 70
# Filename: jirh0pzatszmqg86gzv6c7amcs5asih6.xml
# Succes
# File nr.: 71
# Filename: svy9ev0delutetttup0qh03ee4gpw5ya.xml
# Succes
# File nr.: 72
# Filename: f5u57l3mjhybklvjldt6pcxqaeexq7ge.xml
# Succes
# File nr.: 73
# Filename: 5s2w35u7wrbw0latqew8y7r7ij3fwlu0.xml
# Succes
# File nr.: 74
# Filename: 85rey9bmhmi9mzduksgdfiqd2lck14i8.xml
# Succes
# File nr.: 75
# Filename: wwf5ac7ntbhcs6cjj3u18yqmz9q66hpd.xml
# Succes
# File nr.: 76
# Filename: lv5p3j9xvav27al6g8alvgexmpnpcnbm.xml
# Succes
# File nr.: 77
# Filename: l89j2hpui7i6ecrezwy2kziqmy4pqy2e.xml
# Succes
# File nr.: 78
# Filename: cm45dwado4cqocd3lphp1dral56ztydp.xml
# Succes
# File nr.: 79
# Filename: b85penqoeje2qwx5mt5w8d7csw3lcq07.xml
# Succes
# File nr.: 80
# Filename: ee5u376c1dlttckqx7amxd8jya8w8aoq.xml
# Succes
# File nr.: 81
# Filename: zsnv7bpeyd0368gglbryiwwb5snfgt6s.xml
# Succes
# File nr.: 82
# Filename: l23ma3kwhe7488irqu5iqo27xupj0ro6.xml
# Succes
# File nr.: 83
# Filename: 1wllxbl5vfabbc3qiw70gl36jsqlfab4.xml
# Succes
# File nr.: 84
# Filename: bk442hcb2cduocm3e703gm56c2mdr8ic.xml
# Succes
# File nr.: 85
# Filename: e0povbcvpj7p36p3jwwvou43abew0tas.xml
# Succes
# File nr.: 86
# Filename: ixfv2v6ec4wgbigxqktjekmp15cv5bzz.xml
# Succes
# File nr.: 87
# Filename: jgkwsyar5zuhuj30wrycci9d56799jx5.xml
# Succes
# File nr.: 88
# Filename: z1vsd16dqt5fx1jzfbdhar5k3rcna8bq.xml
# Succes
# File nr.: 89
# Filename: 54ohyxm9stanjfycipup7b0yzysp0k51.xml
# Succes
# File nr.: 90
# Filename: 7omaoq1tkmnvu0iqxcc7cu4or303f7kg.xml
# Succes
# File nr.: 91
# Filename: z9di4ct4f8vq0zo49f8nf8kcjd921jty.xml
# Succes
# File nr.: 92
# Filename: hjenrwyrwq7hikx9xew4txh4lksuhp74.xml
# Succes
# File nr.: 93
# Filename: otdj34pnk5fe4y8qvyy389qbylx3eh0g.xml
# Succes
# File nr.: 94
# Filename: ky1mhrt2n5o19e3ove2lccimwh75ygb0.xml
# Succes
# File nr.: 95
# Filename: ropcrda918fu6gqihkenrg12m2ehhlzd.xml
# Succes
# File nr.: 96
# Filename: 2umhngvytfy2jchpsguk2umwumabl4uu.xml
# Succes
# File nr.: 97
# Filename: 2b542wizazzf6i0jvpurn9cjmfbey5ah.xml
# Succes
# File nr.: 98
# Filename: 3yhxiack3mg1yeljjzjku1l03uitt1v9.xml
# Succes
# File nr.: 99
# Filename: 0zrum6uf87lw3kycksufqyyf9cb0145f.xml
# Succes
# File nr.: 100
# Filename: x2yf51qgg3yncp4otw7ulg396wqph0ow.xml
# Succes
# File nr.: 101
# Filename: i76dc8mxj0js9y5v3pypxio4z9ezm3kn.xml
# Succes
# File nr.: 102
# Filename: isxrik39vsu55uuf0saldse4pblfyak6.xml
# Succes
# File nr.: 103
# Filename: 1kzqhb5fx5jzda24es9i5iz45iv14vgp.xml
# Succes
# File nr.: 104
# Filename: qef10l2g7d7oihl2by6vpyrgtbptbpoe.xml
# Succes
# File nr.: 105
# Filename: ugdohf546mzqwfrx2mnieys80g9oo4w2.xml
# Succes
# File nr.: 106
# Filename: 03qvyd6yvx7sc1ggl0x64h37qqk1ohyw.xml
# Succes
# File nr.: 107
# Filename: j32k71imwgqlejsyj5o4m64x9kalpcks.xml
# Succes
# File nr.: 108
# Filename: p9qzt1ui0ms218ipxyeqgbb4dkszax46.xml
# Succes
# File nr.: 109
# Filename: 9zhzkwtwvlsqgpg5ew8qk8jyvwsz1vf3.xml
# Succes
# File nr.: 110
# Filename: 74vxggadtmyhbs10os852t93365cnkhf.xml
# Succes
# File nr.: 111
# Filename: 53atuirh3kjbjtkvign5tsgqk27t1o1j.xml
# Succes
# File nr.: 112
# Filename: klqcwkmip66iju1famo8e7vv7ejzj5z5.xml
# Succes
# File nr.: 113
# Filename: 9mh3l7ytg4tnce285uo68ck601wd4gdg.xml
# Succes
# File nr.: 114
# Filename: g9vkhd99lmxhd5jbpbwyu3zh59qwk4kc.xml
# Succes
# File nr.: 115
# Filename: th9por2qp4gak4em1zi0j0ty39loloke.xml
# Succes
# File nr.: 116
# Filename: emcvoe23f6nn3c08hoq1ohu637ujqaf3.xml
# Succes
# File nr.: 117
# Filename: 61hpacw5ri5onlufxenjue95bcyk4o7u.xml
# Succes
# File nr.: 118
# Filename: fbc29q1lzks1ujgxu97nvont8uir644h.xml
# Succes
# File nr.: 119
# Filename: pbgbdp87bmwbk0bo7snuzr2peixccvi2.xml
# Succes
# File nr.: 120
# Filename: rdbfoa9al3out55wf6nj2grhtffdwtf9.xml
# Succes
# File nr.: 121
# Filename: cisu18z7nxyp5mazita50k0b1eo5k34o.xml
# Succes
# File nr.: 122
# Filename: q9o5qgvrsrq7o4zt89drrzjcf85ybdjc.xml
# Succes
# File nr.: 123
# Filename: zww9s2kf5f9oym6aehodkduzpjkxho7a.xml
# Succes
# File nr.: 124
# Filename: x4u2dji5fh3uuqz3zmc0sgu9g1cm5bzn.xml
# Succes
# File nr.: 125
# Filename: 1da1c9xs22c5je2inx9tcb5c2j6vwv8c.xml
# Succes
# File nr.: 126
# Filename: 08gb34g7782zv14rkom8xd44s31gsvdy.xml
# Succes
# File nr.: 127
# Filename: ni5xziz558um8pid0hpxu3mri3b3e3gz.xml
# Succes
# File nr.: 128
# Filename: shs0j39el9x7zrsy1j9gyiq0zgfd5vtl.xml
# Succes
# File nr.: 129
# Filename: krma9yn97xpg5i7hecf26s2i9ntf4tld.xml
# Succes
# File nr.: 130
# Filename: vwy5k3fozvopea6ly68hei5ymj6ocpqd.xml
# Succes
# File nr.: 131
# Filename: kbigsswok5hk88sc3wwrxcop25od2hu1.xml
# Succes
# File nr.: 132
# Filename: fg0lz9kxv1wa54ytnp2jjets6vpj099g.xml
# Succes
# File nr.: 133
# Filename: aglk6fybk12rgs0udptzd83vlp1lqyfe.xml
# Succes
# File nr.: 134
# Filename: vzwb9s3x6p3wmmglp8xkxq1ylgwkjdky.xml
# Succes
# File nr.: 135
# Filename: paucsyfo2gvh8wnxzsucil6f5yohrgz9.xml
# Succes
# File nr.: 136
# Filename: 48qj3yl76asxmvb4vhawnv0x69gwplxx.xml
# Succes
# File nr.: 137
# Filename: gsozgmdy5m25rais5l3hl9zsrf4rc77b.xml
# Succes
# File nr.: 138
# Filename: lhl2ka84azzxtouct0zjf54o7061ou7x.xml
# Succes
# File nr.: 139
# Filename: wnwy4a0dap6lg35vwkgb9icem91fyui7.xml
# Succes
# File nr.: 140
# Filename: 33jhojoc8dm4csh61x53oasdhbx9pjmi.xml
# Succes
# File nr.: 141
# Filename: r08adbgnlzjyg9uzmx1l15sqx01q846o.xml
# Succes
# File nr.: 142
# Filename: mfjkwjvvysx001f31kgtho28r5whky0v.xml
# Succes
# File nr.: 143
# Filename: 805mjxmxmurdq8r8rr1aaf74s2s235xd.xml
# Succes
# File nr.: 144
# Filename: g8akqamw5732mlfypmpvpxmopgmmbh7f.xml
# Succes
# File nr.: 145
# Filename: qb82g63nmtlctluzyuebqdv4rt5pdnag.xml
# Succes
# File nr.: 146
# Filename: 0sonr2bq0go8jemif4wib99xsg8s9vn2.xml
# Succes
# File nr.: 147
# Filename: w2bb6sefhxd98ub8njdzmh4irz2dyln3.xml
# Succes
# File nr.: 148
# Filename: k1vampb0allud8d2d8ci06nq4iwkm0kz.xml
# Succes
# File nr.: 149
# Filename: y8rerar0nt82twjozfm0w40gd12mckqa.xml
# Succes
# File nr.: 150
# Filename: r9r0berute6y7881mt3uos8ishwl7zf8.xml
# Succes
# File nr.: 151
# Filename: g2q0q4mte0dhow40y4t2q6hrzqeo07b7.xml
# Succes
# File nr.: 152
# Filename: pwmilco2hfua6o5curw8w761k4d5qupm.xml
# Succes
# File nr.: 153
# Filename: v58cf2cjjnnfkax5yyh0c1jf9wiezqzk.xml
# Succes
# File nr.: 154
# Filename: z98oow5h1kp1vffleg7k1f67s4jv9ibv.xml
# Succes
# File nr.: 155
# Filename: owl24s4mpa2p6sstzdd69ovtur27i4wr.xml
# Succes
# File nr.: 156
# Filename: coe307r79kvu4bfnt6f45n2fad0iya48.xml
# Succes
# File nr.: 157
# Filename: 3o7jdy5lj9dfamjz9kgjx7u9wzw1vhu5.xml
# Succes
# File nr.: 158
# Filename: c5wzfx5xzj97b7oqciosouq2dq8x9moa.xml
# Succes
# File nr.: 159
# Filename: n4nk7zxo6bty7jkge1j70gav30kdpq9o.xml
# Succes
# File nr.: 160
# Filename: t1za44ihj4yk1uirilwp1p2vx65510mg.xml
# Succes
# File nr.: 161
# Filename: u4njesxvx5rz4tmd1pomwr8xx22g1z9q.xml
# Succes
# File nr.: 162
# Filename: meo2gtqzuymiczr6btyhnj0w82whqwam.xml
# Succes
# File nr.: 163
# Filename: mr1zdez5sc0gh77l3zcd48gd5e1niw5o.xml
# Succes
# File nr.: 164
# Filename: q84l8ixsydioobybm6qfy9ex2ym0cwk8.xml
# Succes
# File nr.: 165
# Filename: sps4unn0kbeo6yydehje6v8suzs81w88.xml
# Succes
# File nr.: 166
# Filename: u8ztq7dqfcofc2fjog9xeni2qeflrt4c.xml
# Succes
# File nr.: 167
# Filename: seesxo13br09cwyfz0bkyj866tci2sxv.xml
# Succes
# File nr.: 168
# Filename: p5vk7ul7cxcv9v7dqq9hw8mx9pevt5i5.xml
# Succes
# File nr.: 169
# Filename: 2jyxtsyl2cnqcvl28xyuripr0tij5egw.xml
# Succes
# File nr.: 170
# Filename: io4rg89cm089ag5heikt5dtdg08n4sb8.xml
# Succes
# File nr.: 171
# Filename: b260u4lsi9cly3cjd2z00t6jkt2nfzj1.xml
# Succes
# File nr.: 172
# Filename: lebe831p05hxqg3ix4x1e1onh8o4wfi7.xml
# Succes
# File nr.: 173
# Filename: xl6p5lceu83cg5466ku24o64xfa2na9d.xml
# Succes
# File nr.: 174
# Filename: 1lclx1a9hx7kbs0duhokz2shdd6prd9q.xml
# Succes
# File nr.: 175
# Filename: o0x64lff76qtelo4p64spca43n7t99pm.xml
# Succes
# File nr.: 176
# Filename: ny4ifyl1s5ltmgb8gx1s5lg8d9l5ltzj.xml
# Succes
# File nr.: 177
# Filename: exb0iwu38g9kxnw96lwci69v6l85i13k.xml
# Succes
# File nr.: 178
# Filename: py7z7ooao6ukwgsgvf063tsjh8rgcu4t.xml
# Succes
# File nr.: 179
# Filename: ehkx2bo5bczn8ydga8txdh45woo8akcq.xml
# Succes
# File nr.: 180
# Filename: fyt17hhpznv2vulxw9zbb6orue2lod0u.xml
# Succes
# File nr.: 181
# Filename: 6h96m53scz42e6ax6fcpyivl4xm04xhe.xml
# Succes
# File nr.: 182
# Filename: x2umambvxlv1z998qkmvz1l074kshong.xml
# Succes
# File nr.: 183
# Filename: qf18mf0go02bfilyn1aqn1rpyrwn6vf3.xml
# Succes
# File nr.: 184
# Filename: dhe7bm0noxytbtbksj4a63v1teo8hefd.xml
# Succes
# File nr.: 185
# Filename: 6cb5tsu1o8jacng9cffh70qdwgvwtr64.xml
# Succes
# File nr.: 186
# Filename: hdjo16yiouytvttw9s1q4ld1vd4vzc7i.xml
# Succes
# File nr.: 187
# Filename: 700yr93rdgdysdaqcxq6h4onvn20r8n7.xml
# Succes
# File nr.: 188
# Filename: x82rzykvf94l7x0nqqy39lbqp2iu53do.xml
# Succes
# File nr.: 189
# Filename: p1tyq7405m0u3i4ijdrk6xddm3ynry3v.xml
# Succes
# File nr.: 190
# Filename: 3zqo22cqjgnfrp27t972zf4tvrkskueq.xml
# Succes
# File nr.: 191
# Filename: 2raaquxc4h76t21t1x7su7v0bi4puqwc.xml
# Succes
# File nr.: 192
# Filename: mghbx63q733o3zef21gs6ihed8zsu4am.xml
# Succes
# File nr.: 193
# Filename: 6tq04jhx2m5j0nfqv3kjcvcci3xrt577.xml
# Succes
# File nr.: 194
# Filename: 54avw3ujy0c42aro86ipd4pdy7ts3mhq.xml
# Succes
# File nr.: 195
# Filename: 9jerrymn4bthu3v0p8w1twbvmd1qp7mz.xml
# Succes
# File nr.: 196
# Filename: isvgo0osztr2wwh34nsoa6kntytl32k4.xml
# Succes
# File nr.: 197
# Filename: ygxynz1c8bz70neuyo9eubhlyd8lexgu.xml
# Succes
# File nr.: 198
# Filename: 438z5tr90co6t2f6hij7c09ats33b42b.xml
# Succes
# File nr.: 199
# Filename: 090lrhtfoz1zm7quye676g4ktx597img.xml
# Succes
# File nr.: 200
# Filename: cock2p5mba6ykownk8ulw3szdlnbahek.xml
# Succes
# cunt err 0
#   adding: pan20-author-profiling-test-2020-02-23-augmented/ (stored 0%)
#   adding: pan20-author-profiling-test-2020-02-23-augmented/en/ (stored 0%)
#   adding: pan20-author-profiling-test-2020-02-23-augmented/en/66xfnef04078fl2cjtpl75lcoa3urlw5.xml (deflated 77%)
#   adding: pan20-author-profiling-test-2020-02-23-augmented/en/x8hzj2iwaod69ghfm2trykq4nda7wsya.xml (deflated 81%)
#   adding: pan20-author-profiling-test-2020-02-23-augmented/en/g8f4l0wj2xptb483ivgytzcslwnj24e4.xml (deflated 74%)
#   adding: pan20-author-profiling-test-2020-02-23-augmented/en/6cbcvkpdf0hhh7or4xo9in3iwex4lq0s.xml (deflated 82%)
#   adding: pan20-author-profiling-test-2020-02-23-augmented/en/